# %% [markdown]
# <h1><center>TP2 - Ex.2</center></h1>
# <p><center>Abril 1, 2024</center></p>
#
#
# ### Estruturas Criptográficas
#
# PG53886, Ivo Miguel Alves Ribeiro
#
# A95323, Henrique Ribeiro Fernandes

# %% [markdown]
# 2. Uma das aplicações mais importantes do teorema chinês dos restos (CRT) em criptografia é a transformada NTT “Number Theoretic Transform”.  Esta transformada é uma componente importantes de “standards” PQC  como o Kyber e o Dilithium mas também de outros algoritmos submetidos ao concurso NIST PQC.  A transformação NTT tem várias opções e aquela que está apresentada no +Capítulo 4:  Problemas Difíceis  usa o CRT.
#     Neste problema pretende-se uma implementação Sagemath  do NTT-CRT tal como é descrito nesse documento.

# %% [markdown]
# Estes são só os imports que precisamos para o nosso pograma

# %%
from sage.rings.polynomial.polynomial_ring_constructor import PolynomialRing
from sage.rings.finite_rings.finite_field_constructor import GF, FiniteField
from sage.rings.polynomial.polynomial_zmod_flint import Polynomial_zmod_flint
from sage.all import is_prime
from sage.arith.misc import CRT_basis

# %% [markdown]
# O primeiro passo é a escolha de um $N$ da forma $2^d$ e um primo $\,q\,$ que  verifique $$\,q \equiv 1 \bmod 2N\,$$

# %%
q = 40961
d = 12
N = pow(2,d) #4096

if ( q % (2* N)  == 1):
    print("A regra q ≡ 1 mod 2N é cumprida")
    while True:
        if is_prime(q):
            print(f"q tem o valor de:{q}")
            break
        q += 2*N
else:
    print("A regra q ≡ 1 mod 2N não é cumprida")
    
Zw = PolynomialRing(GF(q),name= "w" )
w = Zw.gen()
# Out:
# A regra q ≡ 1 mod 2N é cumprida
# q tem o valor de:40961

# %% [markdown]
# #### Usando a estrategia apresntada no capitulo 4
#
# 1-Calculo dos monómios s e q

# %%
g = (w**N + 1)
xi = g.roots(multiplicities=False)[1]      
s = [xi * (xi**2)**i for i in range(N)]
q_i = [(w - s[i]) for i in range(N)]

# %% [markdown]
# 2-Calculo do NTT

# %%
def NTT(xi, N1,f):
    if N1 == 1:
        return ([f[0]])

    f_plus, f_minus = split(f)
    bar_f_plus = NTT(xi**2, N1//2, f_plus)
    bar_f_minus = NTT(xi**2, N1//2, f_minus)

    s = xi

    bar_f = [0] * N1
 
    for i in range(N1//2):
        bar_f[i] = (bar_f_plus[i] + s * bar_f_minus[i])#.lift()
        bar_f[i + N1//2] = (bar_f_plus[i] - s * bar_f_minus[i])#.lift()
        s = s* (xi**2)
        
    return bar_f

def split (f):
    f_plus = sum(f[i] * w**(i/2) for i in range(f.degree()+1) if i % 2 == 0) + 0*w
    f_minus = sum(f[i] * w**((i-1)/2) for i in range(f.degree()+1) if i % 2 != 0) +0*w

    return f_plus,f_minus

# %% [markdown]
# 3-Operaçoes basicas do nosso anel

# %%
def subtracao_componentes(f, g):
    return [f[i] - g[i] for i in range(N)]

def soma_componentes(f, g):
    return [f[i] + g[i] for i in range(N)]

def multiplicacao_componentes(f, g):
    return [f[i] * g[i] for i in range(N)]

# %% [markdown]
# 4-Reconstrução do NTT

# %%
def reconstruir_por_crt(bar_f):
    q_i = [(w - s[i]) for i in range(N)]
    mu_i = CRT_basis(q_i)
    return sum(bar_f[i] * mu_i[i] for i in range(N))

# %% [markdown]
# #### Teste do uso da tecnica NTT em uma funçao e de seguida a sua reconstruçao

# %%
f =  Zw.random_element(degree=N-1)

residuos_f = NTT(xi,N,f)

f1 = reconstruir_por_crt(residuos_f, )
print (f == f1)
# Out:
# True

# %% [markdown]
# #### Operaçaoes entre dois polinomios

# %%
############## teste 
f = Zw.random_element(degree=N-1)
g = Zw.random_element(degree=N-1)

residuos_f = NTT(xi,N,f)
residuos_g = NTT(xi,N,g)

op = input("Diga a operaçao que deseja realizar(+,*,-)")

# Realizando a operaçao resíduos
if (op == "*"):
    residuos_resultado = multiplicacao_componentes(residuos_f, residuos_g)
    # Reconstruindo o polinômio resultante usando CRT
    resultado_crt = reconstruir_por_crt(residuos_resultado)
elif (op == "+"):
    residuos_resultado = soma_componentes(residuos_f, residuos_g)
    print("Resultado correto? ")
    # Reconstruindo o polinômio resultante usando CRT
    resultado_crt = reconstruir_por_crt(residuos_resultado)
    print(f+g == resultado_crt)
elif (op == "-"):
    residuos_resultado = subtracao_componentes(residuos_f, residuos_g)
    print("Resultado correto? ")
    # Reconstruindo o polinômio resultante usando CRT
    resultado_crt = reconstruir_por_crt(residuos_resultado)
    print(f-g == resultado_crt)

print("Resultado da operação "+op+":", resultado_crt)
# Out:
# Resultado correto?
# True
# Resultado da operação +: 29288*w^4095 + 40523*w^4094 + 39625*w^4093 + 16819*w^4092 + 1639*w^4091 + 2155*w^4090 + 26903*w^4089 + 3197*w^4088 + 29850*w^4087 + 39590*w^4086 + 1193*w^4085 + 15986*w^4084 + 5181*w^4083 + 23403*w^4082 + 11061*w^4081 + 14832*w^4080 + 10362*w^4079 + 30003*w^4078 + 10737*w^4077 + 10265*w^4076 + 25747*w^4075 + 37810*w^4074 + 32892*w^4073 + 2397*w^4072 + 16546*w^4071 + 16343*w^4070 + 18029*w^4069 + 26891*w^4068 + 9809*w^4067 + 5982*w^4066 + 13313*w^4065 + 27682*w^4064 + 3885*w^4063 + 17724*w^4062 + 40073*w^4061 + 13794*w^4060 + 8791*w^4059 + 38176*w^4058 + 11194*w^4057 + 31041*w^4056 + 34230*w^4055 + 40791*w^4054 + 19161*w^4053 + 30177*w^4052 + 1256*w^4051 + 935*w^4050 + 25952*w^4049 + 17359*w^4048 + 28590*w^4047 + 11211*w^4046 + 22830*w^4045 + 27417*w^4044 + 10166*w^4043 + 17007*w^4042 + 29101*w^4041 + 19261*w^4040 + 40053*w^4039 + 22229*w^4038 + 33188*w^4037 + 14765*w^4036 + 21195*w^4035 + 34770*w^4034 + 25153*w^4033 + 39453*w^4032 + 20535*w^4031 + 37543*w^4030 + 483*w^4029 + 20489*w^4028 + 23294*w^4027 + 16063*w^4026 + 14378*w^4025 + 14614*w^4024 + 24859*w^4023 + 17890*w^4022 + 3382*w^4021 + 32799*w^4020 + 36854*w^4019 + 25432*w^4018 + 25804*w^4017 + 35920*w^4016 + 32759*w^4015 + 5788*w^4014 + 6234*w^4013 + 7270*w^4012 + 17799*w^4011 + 16163*w^4010 + 20347*w^4009 + 34453*w^4008 + 19130*w^4007 + 7667*w^4006 + 25945*w^4005 + 5467*w^4004 + 1898*w^4003 + 4626*w^4002 + 24209*w^4001 + 30763*w^4000 + 25839*w^3999 + 39975*w^3998 + 37721*w^3997 + 25546*w^3996 + 30948*w^3995 + 7637*w^3994 + 11363*w^3993 + 36179*w^3992 + 2696*w^3991 + 6919*w^3990 + 1716*w^3989 + 16216*w^3988 + 15885*w^3987 + 25637*w^3986 + 25854*w^3985 + 396*w^3984 + 19475*w^3983 + 14375*w^3982 + 10585*w^3981 + 6533*w^3980 + 9261*w^3979 + 15753*w^3978 + 26908*w^3977 + 25037*w^3976 + 1981*w^3975 + 19067*w^3974 + 20230*w^3973 + 12973*w^3972 + 4907*w^3971 + 5204*w^3970 + 3430*w^3969 + 37899*w^3968 + 15282*w^3967 + 16293*w^3966 + 3247*w^3965 + 30001*w^3964 + 33578*w^3963 + 32230*w^3962 + 14383*w^3961 + 37977*w^3960 + 9975*w^3959 + 24704*w^3958 + 10036*w^3957 + 34051*w^3956 + 7986*w^3955 + 3022*w^3954 + 32995*w^3953 + 40814*w^3952 + 32132*w^3951 + 15925*w^3950 + 24184*w^3949 + 17421*w^3948 + 31238*w^3947 + 33514*w^3946 + 6350*w^3945 + 20561*w^3944 + 36911*w^3943 + 9300*w^3942 + 5790*w^3941 + 5986*w^3940 + 7092*w^3939 + 3481*w^3938 + 22957*w^3937 + 24344*w^3936 + 36106*w^3935 + 13156*w^3934 + 5606*w^3933 + 20805*w^3932 + 25095*w^3931 + 8466*w^3930 + 36567*w^3929 + 27062*w^3928 + 398*w^3927 + 6058*w^3926 + 29233*w^3925 + 2232*w^3924 + 35457*w^3923 + 23129*w^3922 + 27699*w^3921 + 34113*w^3920 + 20967*w^3919 + 23054*w^3918 + 22417*w^3917 + 32459*w^3916 + 3911*w^3915 + 10476*w^3914 + 29760*w^3913 + 28607*w^3912 + 8178*w^3911 + 22169*w^3910 + 12952*w^3909 + 5205*w^3908 + 22472*w^3907 + 7359*w^3906 + 7065*w^3905 + 19214*w^3904 + 585*w^3903 + 31053*w^3902 + 7324*w^3901 + 28329*w^3900 + 6994*w^3899 + 13050*w^3898 + 36456*w^3897 + 15992*w^3896 + 3421*w^3895 + 11233*w^3894 + 14371*w^3893 + 36277*w^3892 + 9173*w^3891 + 16579*w^3890 + 6758*w^3889 + 27812*w^3888 + 7954*w^3887 + 20696*w^3886 + 859*w^3885 + 19910*w^3884 + 7898*w^3883 + 12502*w^3882 + 33726*w^3881 + 8467*w^3880 + 9761*w^3879 + 6813*w^3878 + 19720*w^3877 + 21963*w^3876 + 22546*w^3875 + 1889*w^3874 + 38827*w^3873 + 21204*w^3872 + 25568*w^3871 + 21103*w^3870 + 6265*w^3869 + 29378*w^3868 + 20049*w^3867 + 10183*w^3866 + 20176*w^3865 + 1496*w^3864 + 35330*w^3863 + 13745*w^3862 + 15824*w^3861 + 9273*w^3860 + 16248*w^3859 + 10988*w^3858 + 29257*w^3857 + 2490*w^3856 + 24266*w^3855 + 34908*w^3854 + 36432*w^3853 + 21166*w^3852 + 14798*w^3851 + 40058*w^3850 + 36341*w^3849 + 14126*w^3848 + 5940*w^3847 + 9465*w^3846 + 10406*w^3845 + 17832*w^3844 + 9942*w^3843 + 39957*w^3842 + 10885*w^3841 + 7110*w^3840 + 17901*w^3839 + 26589*w^3838 + 28538*w^3837 + 6816*w^3836 + 40477*w^3835 + 28461*w^3834 + 17897*w^3833 + 25303*w^3832 + 23026*w^3831 + 36050*w^3830 + 2199*w^3829 + 20498*w^3828 + 39860*w^3827 + 23272*w^3826 + 36350* ...
