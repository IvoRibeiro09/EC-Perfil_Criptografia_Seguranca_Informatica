# %% [markdown]
# <h1><center>TP4 - Ex.1</center></h1>
# <p><center>Abril 25, 2024</center></p>
#
#
# ### Estruturas Criptográficas
#
# PG53886, Ivo Miguel Alves Ribeiro
#
# A95323, Henrique Ribeiro Fernandes

# %% [markdown]
# **1. Implemente um protótipo do esquema descrito no “draft” FIPS 204 que deriva do algoritmo Dilithium.**

# %%
def bitrev7(n):
	return int(f"{n:07b}"[::-1], 2)

def NTT(f_in, Q):
	f_out = f_in.copy()
	k = 1
	for log2len in range(7, 0, -1):
		length = 2**log2len
		for start in range(0, 256, 2 * length):
			zeta = pow(17, bitrev7(k), Q)
			k += 1
			for j in range(start, start + length):
				t = (zeta * f_out[j + length]) % Q
				f_out[j + length] = (f_out[j] - t) % Q
				f_out[j] = (f_out[j] + t) % Q
	return f_out

def NTT_inv(f_in, Q):
	f_out = f_in.copy()
	k = 127
	for log2len in range(1, 8):
		length = 2**log2len
		for start in range(0, 256, 2 * length):
			zeta = pow(17, bitrev7(k), Q)
			k -= 1
			for j in range(start, start + length):
				t = f_out[j]
				f_out[j] = (t + f_out[j + length]) % Q
				f_out[j + length] = (zeta * (f_out[j + length] - t)) % Q

	for i in range(256):
		f_out[i] = (f_out[i] * 3303) % Q 

	return f_out

def NTT_mult(a, b, Q):
	c = []
	for i in range(128):
		a0, a1 = a[2 * i: 2 * i + 2]
		b0, b1 = b[2 * i: 2 * i + 2]
		c.append((a0 * b0 + a1 * b1 * pow(17, 2*bitrev7(i)+1, Q)) % Q)
		c.append((a0 * b1 + a1 * b0) % Q)
	return c

def polyADD(a, b, Q):
	return [(x + y) % Q for x, y in zip(a, b)]

def polySUB(a, b, Q):
	return [(x - y) % Q for x, y in zip(a, b)]

def polyMULT(a, b, Q):
	return [(x * y) % Q for x, y in zip(a, b)]

# %%
import os
from pmain.dilithium import Dilithium2, Dilithium3, Dilithium5
from sage.all import PolynomialRing, GF, QuotientRing, Integer
from pmain.shake_wrapper import Shake128, Shake256
from pmain.utils import *
from pmain.modules import *


class Dilithium:
    def __init__(self, type):
        if type == "dilithium2":
            self.n = 256
            self.q = 8380417
            self.d = 13
            self.k = 4
            self.l = 4
            self.eta = 2
            self.eta_bound = 15
            self.tau = 39
            self.omega = 80
            self.gamma_1 = 2**17
        elif type == "dilithium3":
            self.n = 256
            self.q = 8380417
            self.d = 13
            self.k = 6
            self.l = 5
            self.eta = 4
            self.eta_bound = 9
            self.tau = 49
            self.omega = 55
            self.gamma_1 = 2**19
        elif type == "dilithium5":
            self.n = 256
            self.q = 8380417
            self.d = 13
            self.k = 8
            self.l = 7
            self.eta = 2
            self.eta_bound = 15
            self.tau = 60
            self.omega = 75
            self.gamma_1 = 2**19
        self.gamma_2 = 95232
        self.beta = self.tau * self.eta
        R = PolynomialRing(GF(self.q), 'x', implementation='NTL')
        x = R.gen()
        f = x**self.n + 1
        self.R = QuotientRing(R, R.ideal(f))
        self.M = Module(self.R)
        self.drbg = None
        self.random_bytes = os.urandom

    
    def keygen(self):
        # Random seed
        zeta = self.random_bytes(32)
        # Expand with an XOF (SHAKE256)
        seed_bytes = self._h(zeta, 128)
        # Split bytes em partes para usar 
        rho, rho_prime, K = seed_bytes[:32], seed_bytes[32:96], seed_bytes[96:]
        # Generate matrix A ∈ R^(kxl)
        A = self._expandA(rho)
        # Generate the error vectors s1 ∈ R^l, s2 ∈ R^k
        s1, s2 = self._expandS(rho_prime)   
        #representação NTT de s1    
        s1_hat = [NTT(s1[i], self.q) for i in range(self.l)]
        # Matrix multiplication
        t = []
        for i in range(self.k):
            sum = s2[i]
            for j in range(self.k):
                sum = polyADD(NTT_mult(A[j][i], s1_hat[j], self.q), sum, self.q)
            t.append(sum)
        # Decompor t em t1 e t0
        t1, t0 = self.power_2_round(t)
        # Pack up the bytes para a PK
        pk = self._pack_pk(rho, t1)
        tr = self._h(pk, 32)  
        # Pack bytes para a Sk
        sk = self._pack_sk(rho, K, tr, s1, s2, t0)
        return pk, sk
    
    def sign(self, sk_bytes, m):
        # Desempacotar the secret key
        rho, K, tr, s1, s2, t0 = self._unpack_sk(sk_bytes)
        # Generate matrix A ∈ R^(kxl)
        A = self._expandA(rho)
        # Set seeds and nonce (kappa)
        mu = self._h(tr + m, 64)
        kappa = 0
        rho_prime = self._h(K + mu, 64)
        # Precompute NTT representation
        s1_hat = [NTT(s1[i], self.q) for i in range(self.l)]
        s2_hat = [NTT(s2[i], self.q) for i in range(self.k)]
        t0_hat = [NTT(t0[i], self.q) for i in range(self.k)]
        alpha = self.gamma_2 << 1
        # Loop de tentativa de assinatura valida
        while True:
            # Expandir o rho com a nounce
            y = self._expandMask(rho_prime, kappa)
            # Compute NTT
            y_hat = [NTT(y[i], self.q) for i in range(self.k)]
            
            # increment the nonce
            kappa += self.l
            
            # Multiplication Matrix and y_hat
            w = []
            for i in range(self.k):
                sum = [0]*self.n
                for j in range(self.k):
                    # transposta de A_hat por trocar o i com o j
                    sum = polyADD(NTT_inv(NTT_mult(A[i][j], y_hat[j], self.q), self.q),sum, self.q)
                w.append(sum)

            # Extract out both the high and low bits
            w1, w0 = self.decompose(w, alpha)
            
            # Create challenge polynomial
            w1_bytes = self.bit_pack_w(w1, self.gamma_2)
            c_tilde = self._h(mu + w1_bytes, 32)
            c = self._sample_in_ball(c_tilde)
            
            # Store c in NTT form
            c_hat = NTT(c, self.q)
            
            # Calculate z = c_hat * s1_hat + y
            z = []
            for i in range(self.k):
                sum = y[i]
                sum = polyADD(NTT_inv(polyMULT(c_hat, s1_hat[i], self.q), self.q),sum, self.q)
                z.append(sum)

            # Calculate w0_minus_cs2 = c_hat * s2_hat - w0
            w0_minus_cs2 = []
            for i in range(self.k):
                sum = w0[i]
                sum = polySUB(NTT_inv(polyMULT(c_hat, s2_hat[i], self.q), self.q),sum, self.q)
                w0_minus_cs2.append(sum)
            
            # Extract out both the high and low bits
            r1, r0 = self.decompose(w0_minus_cs2, alpha)

            # Check limit bounds 
            if self.check_norm_bound(z, self.gamma_1 - self.beta):
                continue

            # Calculate c_t0 = t0 * c_hat + y
            c_t0 = []
            for i in range(self.k):
                sum = y[i]
                sum = polyADD(NTT_inv(NTT_mult(c_hat, t0_hat[i], self.q), self.q),sum, self.q)
                c_t0.append(sum)
            
            # Check limit bounds 
            if self.check_norm_bound(c_t0, self.gamma_2):
                continue
            
            w0_minus_cs2_plus_ct0 = w0_minus_cs2 + c_t0
            h = self._make_hint(w0_minus_cs2_plus_ct0, w1, alpha)   
            # Check limit bounds          
            if self._sum_hint(h) > self.omega:
                continue
            
            # Return packed bytes as sign
            return self._pack_sig(c_tilde, z, h)
        
    def verify(self, pk_bytes, m, sig_bytes):
        # Unpack pk
        rho, t1 = self._unpack_pk(pk_bytes)
        # Unpack sign 
        c_tilde, z, h = self._unpack_sig(sig_bytes)
        
        # Check limit bounds
        if self._sum_hint(h) > self.omega:
            return False
            
        if z.check_norm_bound(self.gamma_1 - self.beta):
            return False
        # Generate matrix A ∈ R^(kxl)
        A = self._expandA(rho)
        
        # Calculate mu and c
        tr = self._h(pk_bytes, 32)
        mu = self._h(tr + m, 64)
        c = self._sample_in_ball(c_tilde)
        
        # Convert to NTT for computation
        NTT(c, self.q)
        z_hat = [NTT(z[i], self.q) for i in range(self.l)]
        
        t1 = t1.scale(1 << self.d)
        t1_hat = [NTT(t1[i], self.q) for i in range(self.l)]
        
        Az_minus_ct1 = (A @ z_hat) - t1_hat
        Az_minus_ct1.from_ntt()
        # Multiplication Matrix and z_hat
        w = []
        for i in range(self.k):
            sum = [0]*self.n
            for j in range(self.k):
                # transposta de A_hat por trocar o i com o j
                sum = polyADD(NTT_inv(NTT_mult(A[i][j], z_hat[j], self.q), self.q),sum, self.q)
            w.append(sum)
        # Subtract t1_hat
        Az_minus_ct1 = polySUB(w, t1_hat, self.q)
        
        # Ajust w_prime with h
        w_prime = self._use_hint(h, Az_minus_ct1, 2*self.gamma_2)
        w_prime_bytes = w_prime.bit_pack_w(self.gamma_2)
        
        # Verify sign 
        return c_tilde == self._h(mu + w_prime_bytes, 32)
    
    def set_drbg_seed(self, seed):
        #self.drbg = AES256_CTR_DRBG(seed)
        self.random_bytes = self.drbg.random_bytes
        
    def reseed_drbg(self, seed):
        if self.drbg is None:
            raise Warning(f"Cannot reseed DRBG without first initialising. Try using `set_drbg_seed`")
        else:
            self.drbg.reseed(seed)
             
    def _h(self, input_bytes, length):
        return Shake256.digest(input_bytes, length)
             
    def _make_hint(self, v1, v2, alpha):
        matrix = [[self._make_hint_poly(p1, p2, alpha) for p1, p2 in zip(v1.rows[i], v2.rows[i])]
                   for i in range(v1.m)] 
        return self.M(matrix)
        
    def _use_hint(self, v1, v2, alpha):
        matrix = [[self._use_hint_poly(p1, p2, alpha) for p1, p2 in zip(v1.rows[i], v2.rows[i])]
                  for i in range(v1.m)]
        return self.M(matrix)
    
    def _make_hint_poly(self, p1, p2, alpha):
        coeffs = [make_hint(r, z, alpha, self.q) for r, z in zip(p1.coeffs, p2.coeffs)]
        return self.R(coeffs)
        
    def _use_hint_poly(self, p1, p2, alpha):
        coeffs = [use_hint(h, r, alpha, self.q) for h, r in zip(p1.coeffs, p2.coeffs)]
        return self.R(coeffs)

    def _sum_hint(self, hint):
        return sum(c for row in hint.rows for p in row for c in p)

    def _sample_in_ball(self, seed):     
        def rejection_sample(i, xof):
            while True:
                j = xof.read(1)
                j = int.from_bytes(j, "little")
                if j <= i: 
                    return j
        
        # Initialise the XOF
        Shake256.absorb(seed)
        
        # Set the first 8 bytes for the sign, and leave the rest for
        # sampling.
        sign_bytes = Shake256.read(8)
        sign_int = int.from_bytes(sign_bytes, "little")
        
        # Set the list of coeffs to be 0
        coeffs = [0 for _ in range(self.n)]
        # Now set tau values of coeffs to be ±1
        for i in range(256 - self.tau, self.n):
            j = rejection_sample(i, Shake256)
            coeffs[i] = coeffs[j]
            coeffs[j] = 1 - 2*(sign_int & 1)
            sign_int >>= 1
            
        return self.R(coeffs).list()
        
    def _sample_error_polynomial(self, rho_prime, i):
        def rejection_sample(xof):
            while True:
                js = []
                # Consider two values for each byte (top and bottom four bits)
                j  = xof.read(1)
                j  = int.from_bytes(j, "little")
                j0 = j & 0x0F
                j1 = j >> 4
                # rejection sample
                if j0 < self.eta_bound:
                    if self.eta == 2: j0 %= 5
                    js.append(self.eta - j0)
                if j1 < self.eta_bound:
                    if self.eta == 2: j1 %= 5
                    js.append(self.eta - j1)
                if js:
                    return js
        # Initialise the XOF
        seed = rho_prime + int.to_bytes(i, 2, "little")
        Shake256.absorb(seed)
    
        # Sample bytes for all n coeffs
        coeffs = []
        while len(coeffs) < self.n:
            js = rejection_sample(Shake256)
            coeffs += js

        # Remove the last byte if we ended up overfilling
        if len(coeffs) > self.n:
            coeffs = coeffs[:self.n]
        
        return self.R(coeffs).list()
    
    def _sample_matrix_polynomial(self, rho, i, j):
        def rejection_sample(xof):
            while True:                
                j_bytes = xof.read(3)
                j = int.from_bytes(j_bytes, "little")
                j &= 0x7FFFFF
                if j < self.q:
                    return j

        # Initialise the XOF
        seed = rho + bytes([j, i])
        Shake128.absorb(seed)
        coeffs = [rejection_sample(Shake128) for _ in range(self.n)]
        return self.R(coeffs).list()
    
    def _sample_mask_polynomial(self, rho_prime, i, kappa):                            
        if self.gamma_1 == (1 << 17):
            bit_count = 18
            total_bytes = 576 # (256 * 18) / 8
        else:
            bit_count = 20
            total_bytes = 640 # (256 * 20) / 8
        
        # Initialise the XOF
        seed = rho_prime + int(Integer(kappa + i)).to_bytes(2, "little")
        xof_bytes = Shake256.digest(seed, total_bytes)
        r = int.from_bytes(xof_bytes, 'little')
        mask = (1 << bit_count) - 1
        coeffs = [self.gamma_1 - ((r >> bit_count*i) & mask) for i in range(self.n)]
        
        return coeffs
        
    def _expandA(self, rho):
        matrix = [[self._sample_matrix_polynomial(rho, i, j)
                   for j in range(self.l)]
                   for i in range(self.k)]
        return matrix
        
    def _expandS(self, rho_prime):
        s1 = [self._sample_error_polynomial(rho_prime, i) 
                       for i in range(self.l)]
        s2 = [self._sample_error_polynomial(rho_prime, i) 
                       for i in range(self.l, self.l+self.k)]
        return s1, s2
        
    def _expandMask(self, rho_prime, kappa):
        elements = [self._sample_mask_polynomial(rho_prime, i, kappa)
                    for i in range(self.l)]
        return elements
    
    def bit_pack(self, coeffs, n_bits, n_bytes):
        r = 0
        for c in coeffs:
            r <<= n_bits
            r |= Integer(c)
        return int(r).to_bytes(n_bytes, 'little')
    
    def _pack_pk(self, rho, t1):
        pk = rho
        for i in range(self.k):
            pk += self.bit_pack(t1[i], 10, 320)
        return pk
    
    def bit_pack_s(self, s, eta):
        altered_coeffs = [eta - c for c in s]
        # Level 2 and 5 parameter set
        if eta == 2:
            return self.bit_pack(altered_coeffs, 3, 96)
        # Level 3 parameter set
        elif eta == 4:
            return self.bit_pack(altered_coeffs, 4, 128)
        else:
            raise ValueError("Expected eta to be either 2 or 4")

    def _pack_sk(self, rho, K, tr, s1, s2, t0):
        sk = rho + K + tr
        for i in range(self.l):
            sk += self.bit_pack_s(s1[i], self.eta)
        for i in range(self.k):  
            sk += self.bit_pack_s(s2[i], self.eta)
        print(len(sk))
        for i in range(self.k): 
            sk += self.bit_pack(t0[i], 13, 416)
        return sk
    
    def bit_pack_w(self, coeffs, gamma_2):
        pack = b''
        # Level 2 parameter set
        if gamma_2 == 95232:
            for i in range(self.k): 
                pack += self.bit_pack(coeffs[i], 6, 192)
        # Level 3 and 5 parameter set
        elif gamma_2 == 261888:
            for i in range(self.k): 
                pack += self.bit_pack(coeffs[i], 4, 128)
        else:
            raise ValueError("Expected gamma_2 to be either (q-1)/88 or (q-1)/32")
        return pack
    
    def bit_pack_z(self, coeffs, gamma_1):
        pack = b''
        # Level 2 parameter set
        if gamma_1 == (1 << 17):
            for poly in coeffs:
                altered_coeffs = [gamma_1 - c for c in poly]
                pack += self.bit_pack(altered_coeffs, 18, 576)
        # Level 3 and 5 parameter set
        elif gamma_1 == (1 << 19):
            for poly in coeffs:
                altered_coeffs = [gamma_1 - c for c in poly]
                pack += self.bit_pack(altered_coeffs, 20, 640)
        else:
            raise ValueError("Expected gamma_1 to be either 2^17 or 2^19")
        return pack
        
    def _pack_h(self, h):
        non_zero_positions = [[i for i,c in enumerate(poly.coeffs) if c == 1]
                               for row in h.rows for poly in row]
        packed  = []
        offsets = []
        for positions in non_zero_positions:
            packed.extend(positions)
            offsets.append(len(packed))

        padding_len = (self.omega - offsets[-1])
        packed.extend([0 for _ in range(padding_len)])
        return bytes(packed + offsets)
        
    def _pack_sig(self, c_tilde, z, h):
        print(z)
        return c_tilde + self.bit_pack_z(z, self.gamma_1) + self._pack_h(h)
        
    def _unpack_pk(self, pk_bytes):
        rho, t1_bytes = pk_bytes[:32],  pk_bytes[32:]
        t1 = self.M.bit_unpack_t1(t1_bytes, self.k, 1)
        return rho, t1
    
    def bit_unpack(self, input_bytes, n_bits):
        if len(input_bytes) % 8*n_bits != 0:
            raise ValueError("Input bytes do not have a length compatible with the bit length")
        r = int.from_bytes(input_bytes, 'little')
        mask = (1 << n_bits) - 1
        coeffs = []
        for _ in range(self.n):
            # Extrai o coeficiente aplicando a máscara
            coeff = r & mask
            coeffs.append(coeff)
            # Desloca os bits para a direita para o próximo coeficiente
            r >>= n_bits
        return list(reversed(coeffs))
    
    def bit_unpack_s(self, input_bytes):
        # Level 2 and 5 parameter set
        if self.eta == 2:
            altered_coeffs = self.bit_unpack(input_bytes, 3)
        # Level 3 parameter set
        elif self.eta == 4:
            altered_coeffs = self.bit_unpack(input_bytes, 4)
        else:
            raise ValueError("Expected eta to be either 2 or 4")
        return [(self.eta - c)%self.q for c in altered_coeffs] 
    
    def _unpack_sk(self, sk_bytes):
        if self.eta == 2:
            s_bytes = 96
        else:
            s_bytes = 128
        s1_len = s_bytes * self.l
        s2_len = s_bytes * self.k
        t0_len = 416 * self.k
        if len(sk_bytes) != 3*32 + s1_len + s2_len + t0_len:
            raise ValueError("SK packed bytes is of the wrong length")
        rho, K, tr = sk_bytes[:32], sk_bytes[32:64], sk_bytes[64:96]
        
        # Unpack vector bytes
        s1 = []
        for i in range(self.l):
            s1.append(self.bit_unpack_s(sk_bytes[96+s_bytes*i:96+s_bytes+s_bytes*i]))
        l = 96 + s1_len
        s2 = []
        for i in range(self.k):
            s2.append(self.bit_unpack_s(sk_bytes[l+s_bytes*i:l+s_bytes+s_bytes*i]))
        l += s2_len
        t0 = []
        for i in range(self.k):
            t0.append(self.bit_unpack(sk_bytes[l+416*i:l+416*(i+1)], 13))
        return rho, K, tr, s1, s2, t0
    
    def _unpack_h(self, h_bytes):
        offsets = [0] + list(h_bytes[-self.k:])
        non_zero_positions = [list(h_bytes[offsets[i]:offsets[i+1]]) for i in range(self.k)]
        
        matrix = []
        for poly_non_zero in non_zero_positions:
            coeffs = [0 for _ in range(self.n)]
            for non_zero in poly_non_zero:
                coeffs[non_zero] = 1
            matrix.append([self.R(coeffs)])
        return self.M(matrix)
        
    def _unpack_sig(self, sig_bytes):
        c_tilde = sig_bytes[:32]
        z_bytes = sig_bytes[32: -(self.k + self.omega)]
        h_bytes = sig_bytes[-(self.k + self.omega):]
        
        z = self.M.bit_unpack_z(z_bytes, self.l, 1, self.gamma_1)
        h = self._unpack_h(h_bytes)
        return c_tilde, z, h
    
    def power_2_round(self, poly):
        t0 = []
        t1 = []
        for i in range(self.k):
            r1_ = []
            r0_ = []
            for c in poly[i]:
                r_plus = Integer(c % self.q)  # Certificando que r_plus é um inteiro do Sage
                r0 = Integer(r_plus % (2^self.d))  # Usando inteiros do Sage para operações de módulo
                r1 = Integer((r_plus - r0) // (2^self.d)) 
                r1_.append(r1)
                r0_.append(r0)
            t0.append(r0_)
            t1.append(r1_)
        return t1, t0
    
    def decompose(self, w, alpha):
        w0, w1 = [], []
        for i in range(self.k):
            m0, m1 = [], []
            for c in w[i]:
                #def decompose(r, alpha, q):
                r_plus = c % self.q
                r0 = Integer(r_plus) % (2 * alpha)
                
                if r_plus - r0 == self.q - 1:
                    r1 = 0
                    r0 -= 1
                else:
                    r1 = (r_plus - r0) // (2 * alpha)
                m0.append(r0), m1.append(r1)
            w0.append(m0), w1.append(m1)
        return w1, w0
    
    def check_norm_bound(self, matrix, bound):
        for row in matrix:
            for p in row:
                if p >= bound:
                    print(p, bound)
                    return True
        return False
        
DiliThium2 = Dilithium("dilithium2")
DiliThium3 = Dilithium("dilithium3")
DiliThium5 = Dilithium("dilithium5")

# %%
# Example of signing
pk, sk = Dilithium2.keygen()
print(f"Public-Key: {pk}\nlen: {len(pk)}")
print(f"Secret-Key: {sk}\nlen: {len(sk)}")
msg = b"Your message signed by Dilithium"
sig = Dilithium2.sign(sk, msg)
print(f"Sign: {sig}\nlen: {len(sig)}")
print(Dilithium2.verify(pk, msg, sig))
# Out:
# Public-Key: b'\xb3{ze\x89b\xe2\xc2\x8b\xb1\x1ab\x9a\xdc\xf0\xaa\x9b\xb4&2\xc5\xbdW\xe9\x8a-Q-%U^\xa8\x80\x89\xcbs+\xa2\xf2\xa0\x85\x89o\x8f\x0c\x95\x82\xf4V\xd0\xcd\x15\x18T\x82H2\x93V\'\x02\x165\x92\xb0\xca\xb2\x10I}D\xff\xf3\x88(C\xb5\x867=\xf5\x92\xfe\xc3\x87\x00\x81\x82\x13\xfb\xb3\xbb\xd3uGR\xcb\xa6`0\xde\x8e7\xa6"B\x1d\xf6\xcf\xde\\\xc9\xb0\x8d\xc2\xd1\xef\r>\xe9\xfa\xf6\xe7\xaa EJ\x14\x9e\x8b,\xc36\x90\xad\r\x8f\xe5\xe5j\x0e|\xabn6.\xc7C\xd5\x15\xdb\xb1h\xd6\x9f\x99\x81+\xe3\xff"\xbe\xcd\xf4\x9eKeS)\xa9\xcd\xb7\xdc\xe9Ebc\x04\xcb\xe9\xe7\x93\xb2WB(\x84\x1a?|Q^UT\xec\x12\x97\xab~\x95\xb2\x84!\xd6\xbd\x11\xb3\xde\xfd\x9f\x9cq\xc5\'\xc2\xb2\xf7Q\x9d\xace\xe8\x02\x95\xceG\xbc\xec\x07\x7f\xf8\xfc\xb2~\xe7^\xc9^\x1f\xa5\xcfX\x9dn\xcb\xeb\xbc\xfa\xd6k\xe1d{\x02\x12#\xd6A\xe1\x1eN"\xd5\xc1\xd1\x1ca(\xdah\xc2\x1e\xf8{B\xe1D; \xc0\x80\xc2\x90\xad\xbc\x98\x9b\x13\xbc#\x8fQU\xfe\r\xf5I\xae\x1b\x02A\x98\x0c\xa0\xfa\xfd\x1fF\xe8#@\xeb\x82\xb2\xb57P\xec\xc0\xe9\x86\xaeE\x01\xb5\xcbo(\x80\xc5+\x1b\x9a\xf8\xa7)N\xcf\xc2\x9e\xae\xc5\xd2\x80\xe2\xc6\xd86xB\xd5\xb7CT\x9c)5\xd9\xfc\'\x1b\x8d\x8e\xae\x1d-b8\xf8\r\xe6\xde\x9a\xf8m\xfe\x88\xec\xa9r\x8bv\xcemE\xa4\xa7\xb1\x0b_Ae\x94\xe7I\xa2\xf9\x13\xb1\xdcP$u\x0b\xa9\xe4\x10\x06\x14CM\x9e\x15\x8fj\xc03\x1a\xa8HMA\\\xbb\x11>P\x05\xc6\xc3\x7f\xf3\xa9\x9cZ\xd0B\x9f\xde21r\xcc\xf5?\xf9\x9a(G\x1c\x9e\xed\xf4Zv\'\xf3\xf3U|\xe5j[\xd5Z\xc1\xf67$}\x9e\xe6\xf1\x87\xefg\x8e\xe6i\xfd\x19\xbdt\x9e0\xda\xef\x8c!\n>Q\x891\xa6\x14\xf9\xc0\x1cX\xf6}\xc0_:}u\xd3\x99\x8f\xe7Sc\xe4\xbe\x08\xd51/\xa05!\xa1\x0f\x0bM\t\x01ik\xf0\x19\xfc\xf726>w\x13D\x0bE\x0e\xc50l\r\x1a]\xeb\xd2J\x9d\xbaj)\x9a\x06|\x9b\xfb\xe7@zX\x1eH\xc7\xc1Q\xd7\xf8\x1at\xe6L\xab"\x9e2I\xc9\x19\x95\xba\xb2\xdf\xbe\xd9b\xaf\x9b\xe5\'j\x0eT\xdb\xba\xd9\xdf@n&\xc3\xd5_?}\xe3CA\x8fU\xb8n\xf7\xfc4^\xb1K\xb6E\xbc\xce\xdd\xa3\x13\x81\xd8_G\x94\x8c\xe1\xc0J[J\x96\xbf\xf1\x8a\xcc\x93\xfcq\xf8\x7f \xc9\xea~\x95\xaa\xcb\xa9\xd5[\xf8\xdb~\x03\xddpHJ\x9aa\xc6\x8f\x00\xc4\xc4\x8e1\x04v\xa8\xae\xf1\xe7\xf3\x1cD\xd1\xca~J\xbe[G\xe5\x94\x8a\xf2\xc8Sa\xac7\xb9\xdc\xbf\xc8$\xde\xf3#\x05\x84\x94\xdd\x8a~\xb4\x89\xfb\x17 D\x0c`\xc6\xf7}\xa4\x0b\xf6{\x85Wm*=\xdd\xea\xc1\xdek\xfa\'v\x94l\xaf\xbb\x97Y\xf8\xfd\x1e\xa7~\xaa\xe9I\x8c\x87\xd0?1\x92]\xd0\x8d\xf2\xccP"\xa9\xff\xb8Z\xd1\xb3Pv\x07\x877F\xee\xcd\'\xa9\x03\xdf\xbd\xd8\xedV@\x10\x80\x1c*\xaa,\x05WP?\x0b\xd6\x93\xc2x+\xc4\x06]L\xb8|\xe5q\xb3\x82zQGdwH=\x98\x1d\x897~\xa5 \xe9\xc9\x01\xb9\xbe\x07\xcdx\xf34\x9f\x8cne\x9d\x89\x172J:\xf6\xa3\xb1\x15$\xd21ObO\xb9S\xc4{1\x90[4\xedD\x1fD\x9a\x84S\x8bUQ9\xb0`\n\xbd\xaf\xdd\x1d\xbf\xb0\xd7\xb5\tU~\x04\\\xa6\xa9\xa9\xf9\xde\xcd1\xe6\x9b}\x80\xd3U\xa6\x89Y\x7f?\x17x\x1aJbL_\x9at\xb7\xb8-)\xac\xcb\x19\x08\x90U\xa0\x1c\xfb\x17G"\xcc\x16\xd6!U\x01\x80\x98\x7fBy`\xa7\xbc\xab\xb2\xaf\xfcv\x97%\x86\x90No\xddc\xa8\xe6y\x13\xeb*{=\x9dK\xb4_8\xa2X\xc5\xfdc\xb6D\xe5\xc2\xd4\x1b\x82\xe4\xf7\x8d\xe1\xb6c+$\xf0\x85\x900o\x88\xa3\x82\xaa\x7f\xf5\x84\xef\xa7\x952\x14\x84\xdd\x05\xd1\xad$\x8a\x13\xb6\x17\xa2\x9dik\x07@\xb3\x93\xdc\xe0\tb\xa5\x91\xc7\xe6\xe9\x10,\x92\x05C\xda\x97\x08;\xe6\xc6\xbd)<-\xb8\xc1\x0bA\xe6\xa0\xe1\x07\xe8[/\x99&^pI\xd4!\xf1\x9ay\xdf6\x90\x9f4\x13k\x96\xe1F\xe8\x8a\x97\x14j\x84r2\xce\x9d\xe0\x99\x1d\xe6\x9e\x10:\x11}\xecb\xe6p\xc5`I\tB\xc8\x90\xf9;\x08\x97\xca\xd1y\xf1hO\xab\xcfA7\x84\x8eG\x8d\xca%$\x96.\x98\x15\xf3\xdc\x13V\x02\x0b\xfb\'\xb0\xab{\xc0\xc5\xd0\x9b\xabBw\t\x9c\xc2\xae\xe1\xe3\x07\xa47\x12<\xa7\x83L\xe9\xe9\xd8\x12,\xca\xab5\x05*\x8c\x85\xe8\xed\xe0ikUo"\x14s\xe5w\xdcV\x19k>\x0e#\x1f\x1beb\xb6\x10\x9f&\x10\xa7\x9f\xb3\xb0\x13\x9a\xee\x93\xe8\xf9`\x02N\x12\xfc\xe9\xeb$\xa1hi\xff\x88\xab\x1c\xbe\xff\xf4\xa7\xa4\x9a\t-\x8c\xc7\x17\xed\xbcJ\xdaQ\xee\xc8\xda\xbff\xf2G\xd7\xcc_\'\x97m\xc1P\xce}F\x0e&\xbc\xf6\x16\xeb\x00\xe9\x92\xfdK\xd0Q\xa0\x16G~d\xa34\x1e\x81^\x1f\x8c~`\xc4U\x91\xc8s\n:'
# len: 1312
# Secret-Key: b'\xb3{ze\x89b\xe2\xc2\x8b\xb1\x1ab\x9a\xdc\xf0\xaa\x9b\xb4&2\xc5\xbdW\xe9\x8a-Q-%U^\xa8\x988~\x0c\xdb\xa8YHo\x03\xaf\xba?\xd1.\xe5v$:\xfei\xcd\x11\xe9_\xe04\xackI\x93b\xb4\xf8\x1c\xca!\xcbB\xa3\x91yxL\x03\x8a\xbbO\xe8\x18|\xe5\xa0_\x89F\x9aC<+\xd1\xda\xa1\xa6\x0c(JJ\x10$\x03\x05\x90\x08\x17\x12c\x82\x11\t\x90\x88T\x90H"FF\x04\xb5P\x12\xa8`\xe38\x8a\x9cH1Y&1\xa06\x0cJ&H\x02E\x8e\xd8\x16\x04\\\x90 \x01\xc8i\x0c$\x86\xe4\xb6\x85\x08\xa5\x84#\x94ED\xc2\x00\x015r\xcc\xc0H\x19\xa2\x85\xcb\x98a!\x90d\x8a\x98i\n\x96\x91!\x16\x90\xc4(\r\x1a6\x91\x00IF!3\x00Q6J\x03\xc60\xa1HH \xb8\x8c\x0c\xb3\x91\x04\xa5\x90\xe2\xc0\x01\x14\x17$\xc8"\t\xa0\x06\x91\x9c$\x90\x1a\xa4mY6\x8e\xd3\x16\x80\x12A\t\x94D)\x89\xb0\x80R\x16@\x1b\xb5HI(\x04!\xc3qc"p\xa02m$\x891#AL\x90@\x08P\x96q\xdb\x94\x8db\x12\x86"II \x19n\xdb\xc4\x84\x12)m\x84\x90(H\x84\x88Z6\x91$E\x08\xd140\x19FB\x1cBb\x03\xc6\x10\x84\x18M\x1bA\x90J\x18\x02\x14!q\xe3\x08\x89 )!!\x99\x88#\xa6a\xa20\r$\x86\x11\x10\x88\x8c\\\xb2D$!H\xa00\x8cS\x94\x8c\x1a\xb0\x0cL\x00\x04\t\x801\x0c\xb9`\xda\xb2P\x114R\xe3\x82L\xcb\x04,Q\x94I\x08\x04\x88\x03\x810\x1c\x99@Z\x94%\x89\xa4(\xd82\x00\x125R\x8a\x16\x02\xd0\xc8\x04P0*\x10"\x06!\x01\x89I\x96\x04\x10\x98d\x19 \x01\x02\xc5,\x1c\xc1 c\xb8`\xc8"h\x88\xc6%\x14\xc8h\xd9&J\x0b\x14n\x00\x85)\x90\x06\x08\x12H*\x01\xc0!$\xc0\x90#\x15\x10\t\xc4\x10!H\x80\xc9\xb2h\x81D2#\xb0@\xc0HQ\x14\xb0\x04\x980R\n\x11\x92[Bh\xdb\xa4\x04\x11\xb6\x90"4\x88\x1c\x07qY40\x08\xc1p\x846\x92$\x15Q\x12\x05\x80\x81\xc0\x8d`00\x03\xa9\x84\x18\xb0\x11\xe3\xc4\t\x9c&JB(!\x04\x82H\xe3\x10\x81"\xc4A!\x87p\x84\x12J\x18\xc1P\n\xc8\x04Y\xa8`\x10\xc1a\x84$&\xe3\xc8l\xc1\x88\x0c\x1b\x17ab4\t\xe1HI\xe3\x18b\xa0\x18\x8eX\x06\t\x03!\x04\x10\xb1\x81\x12\xa8mP\x96q$@\x08L8`\xe2\xc4L\xca4A\x88\x00\x85"BL\x02 ,K\x08\x85\x9c8J#0@\xc0\x16\n\x08\xc4\x10"\x92M"\xa5mPFMZ\xa2q\x92\xc8%\xa3D\x0cX\xb6h!\x12"\x19@*\xd3&.\x03\xb9Q\xc4@d#GB!\x83l\x19\x95\x04\x93\x92\x8db\xa8l\xe4(\x80\xc0&\x00\x910.\x00B@[\xc8a\xda@QC\x90d\xd8\xb6\x88b\x86\x04\x1a\x05JT\x10I\x14\x08\x0e\xd3B$`\xa8 \\\x08m\x118l\x1bEr\xc3\x14b\t!\x0e\x0b\x11\x89`0L\x02\x981\x1b\x98\x0cC\x14J\xd3B\t\xdb\xa8!\x1a\x07P\x1cE%\x08\x14R\x0c\x05-\x8cFM\xc9\x14\x85#\x07\x04A4\x8a\xa2\xa8L\n6!\x14(jZ\x02\x06\x83\x98l\x0cF*\x9c\x04l\x9a \x0cR\x96Q\xc4\x90\x89\x91$a\x13E)\xe3\x00J\x11@r\x11\x03\x90 \xe3\xaaY\xd5\xe2\x00\xe7\x81\x14=\xa2\x1c\x1f\xc2\x98\x1c\x8d\x88Z\xc3\x1cVo{\xf1b\xa7\x80C\xa7rc\x8f\xd5\xb9N)\xa5\xf4\xf1\xf00f1\xdb-\x0b1\xe7\xc5J\x88\xff\x1d`\'\x11\xfc\x1bx\xfc\x9ej\xce\xf1?\x91\xa4k\x88\x97k<\x91:8\xa5T\x16\x04T\xf466\x83 \x85\xf6\xf1\x9d\x1b\x00E\x8d\xde\xf8\xe5\xcdp\x1a\x83\xfb\xcd\x900H\xe1\xb7\xd0\xcc2DG\xde\xd5:\xc8m\x8d\xa91\xe3\x92\x9a\x9a5\xf5\xcb`\xba\xc3\x05\xd5\x9c\x8eph\x94\x10\x1c\x14\x1e\xb9\xfe\x15,\xcf\xce\xaem&\xff\xb0\xe3\xe2\xb2\r\x98u\xaeeR@\xdc^\xe8\x8d\x97\xa4W\x00\x0eOO\x0ft\x00\xde\x94\xd7\xc6\x05\xff\xc2-\xc4\xf9\xba{\xcf8\xa7\x92\xc7^\xf1\x87\x16L\xa2\xf3\xdd\x16~\xf1\x1f%\t\x89\x8d0\xb4\xf5\xf5<\xf8\xf2%\xca\x80x\xb2\xf8K\xa6\xe4\xb9\x1dr\xf4\xcf\xe9\xe6\xa3\'\xb1\xfaN>\n\xfb\xf3\xc8\xb1\xee \x91\x04i\x91(!\x89\xf45\x7f\x82G\x8e\x01\x15\xdc\xdc\xbdt\xeb*Xy\x8a%\xcf{T\xf0!6\xe0\xc1\x7f\xe5\x02\xd9\xbe\x86\x0f\x05{\x08\xdbT\r\xe5\x19\xf6\xe8\xdb\xf3e\xbb\xd2<2\x0bKn\x92\xeb5\xbc\xf6\xa8\x81\x0c@\xc3\x01\x92]\xb0\xb7\x94\xf2\x8f@\x8f\xa3\x7fL\x9a+\xf6\x9b\xda\xdc\x7f\xb5\xd3\xb6p\r\x00D9;U\xc7\x02rN\xc3\xfd\xe8n\x0e\x13H_%\xd7\xf1\xd3\x81\xd6\xd3\x92\xde}\x8dQ\xeaf+o\x06\x9b}\xbd\xdb\xc0I\xf445\xb4s3\xc3\x9c\x81\xfb\x9a\x11XP\x10\xa2NC\x1d\xc9\x1a\xd6/\xdeh\x88U\xb6\xfcR<[\xb9\xbb9is\xf2\x9e\xa6R\xbbU\xb2\x85?p\x91x\x1b\x8b\xd0\x91\x99\xc88M\x0b7D\x02k\xd1"\x00\x1b\x969%UDY/P\x0c\xcd\x06\xd3\x98\xf86\xae\xc1\xc9\x03\xd3\x9a9\x15I}\x82\xb7\x85bD\x07/\x1f\x19\xc0\xd2s\xf86O0tZ\xab\xc1\x7fL^\xf88\xa4\xee\x8e\x89\xa9\xd2\x01N\xb6s\x12(\xb4\x15CF\xceNV\xca<\x9b\x96\xe6\x13}\xf5.|4\xa0\xee\x96 \xc63y\\)P_\xcd\x14\xa4\x8a\xfd\xbc\xc6\xb5\x06\x1a\xa0\xf2Sl\xa7\xf5\xc3\x05 \xcf\xbd\x1f\xea\x1c\x0f$o\xd26\xfb\xb0\x12\xc ...
# len: 2528
# Sign: b'+\x93\xdbN&)\xae\xb9\xf2\x16j\x89_\x00\x1fa\xe8\xcc\xeb\xe2\x10\xc7@\xb4\xb7=\xcc,\xd5\x00\x10n\xffd\xf1r8R`}v0\xfaJ17\xd5\xb0\x06\xba\x86\xe7\xd9m\xc7o1\x06\x87\xda!\xbe\x82d~9\xd5\xb5O\xa4\xbc\xdf\xd9CGq\xaf\xb6\x7f8\xc8\x1dc\x89\x9et\xe5l\xdf\'\x1dO\x1d\xb1c\xc9\x0b*a\xe8\xc4\xba\n(\xcc\x88se\xeb\xf9^\x13T3\x9eM:\n\xc2uE\xa1qC\nH\xd7/]\xc58\xde\xd1\x90\xfc\x0e\xfd\xf1==\x199}|\x9f/PQ\xf3\xc7\xd5\xe6+\x9f\x1c\xacm\xe5\x90B\xac_\xb2\xe4E\xa4%\xc8\x08\xba\xe2\x1c\xadF\x03\xd0\xee?hx\xecY\'R\xf0\xc9\xb3\xed\xdf\x95C`\xc9\x17%\x88(~S\xdc4\x7f\xb5gOA\x83z8\xa8\xdc\xa0\x16p\xb2o\xea\x8a\xd9\x896\xb3N\xbe!K\x1fO\x01\xf6S\xb2"\xda\xad\x91\xff=\x96\xc1\xbf\\1\t+|b\xaa!\xfa\xb7$*\x96"\xf6\xb5k\xf2\x1fe+\xed9\xec\x12\xb7N\xf1\x1f3\xce@.\x0f\xc6\x90\xd3\xb2\x8c\x94\xc2\xd2\xdd\xf4j:\xed_\xff:m11\xba\x9b(\x89R\xa2\xbb\xa73\x11\xb7\x91\xec\xc9\xc7\x1e\x8d\xfe\x88\x13\xa4\xa4\xaf4/1\xb6\xee\xda\xf8#\x9d\xa9m\xd9\x00\xd2\x8eu\xf8\xc5\x0c\xa8\x819Qd\xe1\xf3<\xfav~:-w{\x1b\xb8\xb7of\x81\x85\x0b\x9c6\xa3\xc1/\x1b\x8bU\xdf;\xef\xf7\xbf\xce\x8a\'\xf1\xba{p#\xcf`n\x9e\x99\x8c\x87\xc3\xc2\xa6\xb7\x99\xf4\xdc\x0b6\xaf\x1aqk\x1b\xf7\x02\x15\xcc\x98l\x11\xaav\x8b\x0c\x0ei\xe8\xdb\xfc\xfbp9\x91\x96\xd6"\xcdZ\x91\xca\xb2\x9a\xc6\xf2\xc8\xc4@="\xa5\x03\xd5\xe3\xe0\x8a\xc0\xf5\xf2\xd5)\xa7\x7f\x81Z\x9c\x8e\x9br\x9d\x11)\xcb\x0c\xd2\xec\x13\xad\x1c\xb8_\xc2@\x17\xda\rZ\x02\xf8Kg\xab\x85!#kk\x14m\x1bl\xfbR^\xa7\xe7\xa5o\xe5K\xf9U\xd2\xef\x83\xbbK\xf7\xe2\x16\xe3<\xd3\x1b\x91y\xe6\x1d\xc1\xda\xe4\xe5\xc1\x0f\x95\xa1\xd2o\x9c\xca8y4P67\r\x8c6\xe7\xfa\xb3Geb\x1eC\xc2~\xfc,\xad\x85\x8d\x8f(@\xc4\x9bs\x91\x03\xc6\x8f\t\xcf\xc3\xdc\xc9\x93I\x19\x07\xf2b\x13\x99\xd2\x1a\xf6\x90a\xab*7\x96\x0e\xd8\xfa\xc4#\x8f3{55~N\xba\x0b\xc7\xb3\xd7\xdc\xe1\xcd;\x89\xd1)S\xe2\xfe\x8c\xcc\xaf[g\x86\x86\xbf\xc7\xfc8Vs|\xd9\xbd\xea\xc7\xb9u\xa7M\xb8\r\xe4\x89\rN\xaa\xda\xba\x12t\x0e\x8f\xfa\x18g\xec\xceB\x10\x07\xae\xe6\xc6\xd1S\x84\x82\x18\xab\x0f\xe4\xda+\x03\xbc\xaf8\xc6 8R\x92\x1d\xd2~\x08\x90\x86\xfeV\xb8\x84E\xbb\xc5G\x81h!\xf1\xbb>\xe4\xbcn\x8a\x93\x95\x93\xfa\x1e\x92B\xd6Vv\r?\xc5u\xa2\x80&\x9b}+\xaaT\xd9Z.\xf1\'\x13P\xea\xe5a\xb4\x11\xd5\xe0\xf5\x1d\xa8a\xfa\t8\xdf\xf1\xecD\x80\xf7\xce0\xef\xd0\xab$`\xae\xfc\x0c\x9d\x10<\xc7|\xd4=\xc2\xe7\x88\xbc\xfc\x9d9Q\xfa\xd8;\x95_N\xc8*\xf6\x9a0\xc1\xe6\x174fx\xf2}_L\xd5\xf7\x9cc~\x1bC\x88\x8f\xe6\x80\xbb\xc05\x92w\xd5Y\xa9\x06\xc6\xf69\xd8\xcb\xbf\xd4\x8ed\xad\x8a \xe9\'\xc3\xfb(91\xb2(\x939\x91F\x82\xa0\xde\x15\xf5\xc8Fvl:W\xaa]|\xc3\t\x06i\xa0\x8f\xb5\x8fY\x97{\x13:\x9f\xd1\xad\x8e%\xd9\xe0\x04Uf\xe8B\xae\xb9\xd8l\xbf\xd3\x9b\x10\xb2i\'\x9a\x9e+B,\xbd\xbd\xaa\xcc\xfd\xc6\xd6S\xfeh\x17AQ\x8e\xe3\x16 \x87\xff\x11\x90\xf8&(\x1a\xea\xc4\x13\x01x|M\xdc\x98\x80\x80j/3p\tC\xbd\xb4{\xb2\x10QR\x9e\xf1f\\\xb8\xf3R}\xde\x0b.\x0e\xd4\x06\xceE{\x16\xd4Q\x93\xd0\x02\x1d\xf0\xc2\x1a)N\x17v\xac\xad\xd4\xd5\xd9+L."\x1bP\x03>\x18\x1c\xfde\xb7s\xfa\xcc\x89t2x[\xa9\xc0X\xaf\r]\x12$\xa3\xb4\x9fSw\x16\r\n\xc1\x18\xaa\xc4\xbd\x9bvm\x8a\x8f\\b\xa0\xb2\x9a\x89\xd9\xc3\xd5\x07\x9a\x95\x11\xb9TVNC\xa8\xbc\x1c\xae9M\xb1O\x98\xa8\x80\x13\r\xcd\x98-\xe3\x1a x\xdc!/U\xf3!\x02\xbdC\xa6.\xc8\xb4\xd9\x05\xf0-\x95\xf68\xe0\xdd4\xb4\xbfyR\xf0\x1f<\xaf:\x87\xc2\xb4I\x02.\xdbXcv\x99\x8b\xb6\xc9\x82\xbbN P\x9a\x19\x11}m\xb3\xe2\xf3<\x02V\x1b\xa0\x0e\xff\xff}\x08\x88)\x06KT\xfe\xac\xa6\x9e\xc3\x85\n\x11\x86\xe0\'db\x89|8\x17\x13\r<\xa3\xad\x99\xd9\x1d\xad\xea\x04\x8c\xcbS\xd5\xa1\xf6\x8c\xf2c\xe4JL\xd0\x17`_qwk\xb8\x97J\xc5f\x00\xa2\nDA\xd2f\xa0G\x90\x12\xc4\xa1\x86\'\x9ci\x90\xb3\x02M\xb0\xe5\xef\xd0\x90\x95\xe3_\xd7\xbad\xc8\xb98E\xe3^2 \xe9\xe1\x19\xf8C8\xea\xc2Z\x1e\x16\xca\x82\xb0*R\x87\xbc4^\xdeUf\r\xf0\x9aJ\x84\x0f0.\x92(\xa5Y2y\xfbG\xce\xf5\xf5\xa5W\xe8M\xb4\xd6\x8a\xe1i\xd6\x9b\x00\x9e\xa8\xcaX\x88\x08\xe9\xe3\xef\xc6\n\x9b\x118\xcd\xe4SM\xc6\xb5_\x99\xf9\x96p\xb3\xeb\x8e\xfe\x18\xb0\x1c8\xeb"m\x81;\x8bx\x83\nsW\xc7}\xf6\x84\x95\xe8PpQG\x95\xb7b\xe9x\x93\xc9r\xac7\x06\xcaxF\x93\xbcNz|\x0e&\xcb\x03a\x10\x182OYt\xa3\x97V\xdd=\xf9\xd5\xbcG\x90\x7f\'\x94\x ...
# len: 2420
# True

# %%
pk, sk = Dilithium3.keygen()
print(f"Public-Key: {pk}\nlen: {len(pk)}")
print(f"Secret-Key: {sk}\nlen: {len(sk)}")
msg = b"Your message signed by Dilithium"
sig = Dilithium3.sign(sk, msg)
print(f"Sign: {sig}\nlen: {len(sig)}")
print(Dilithium3.verify(pk, msg, sig))
# Out:
# Public-Key: b'\x8c\xb3"\x90G\xcee\xe7\xf6\xbcb\xe5p\xea\\\x047\x81 \xec0\xc1\x18\xc4\xde\xc1\n\xe57\xdf\xf3\xa2aa;H\x1e\x17u\xa4\x8f\xb51\x80\x17)\xbe\xb1\xef\x1cY\xfbku3\xb7\x85\x7fQ\x88}\xcbo\x9a\x8aZy2\x97\xd4\xb6\x07\x17\xd0\\\xf0\xea\xec.)\x87\xfb\x12K-\x99\x9a\x91\xf3[+\xc7$\xce\xd8\xf0B\xfa\x86\xfe\x1a\xa1\xb5p\x82\xf1M3\xdf \x16\xb6\xfc2\x12\xbe&\xc4\x06\x86\xcd\xe7}\xdd\xaa\x14X&\xe8\xb6U\xff\x12\x1a\x9c\xb0\xf7\xfc\x15\xa0\x0b\x9a\x0f\xa1-\xc0\x15\x7f:(\x11q\xce\xba\xbf;\xc3K\xfe\x84\xbb\xea\x11\xee*\x87\xc8\xa3S\xad\xea\x16-w\xd4Z\x12\xf3\xab\xd7\xb4\x9a\x9d1\x85\x1b\xbd\x89\xb2B\x83H5\x8e\x0c\x9f1\xfcyI\xb1\x08]\xb1\x8fr7U\x94\xbeJ\x87\x08\xc8\xdb"@9v\xd4\xd6`\x9fL\xc5\xd9\xb0\x88\x80\xbaU\x87\n\xc5\xa8\xf5Y\xaa\x0e\x04\x92Fh\x93\x04\xde\x96\x12r\x10\nXD4>1sG \x99lWt\xaa\xd2k\xafoe\x14.\\q\xf5l\x00\xca\xef\x1d9;i[\x93\xcc!]\xd9b[\xe2\x0c\xfa\xe8\xfa\xcdp\xd0\xd9M\x12\xb8&\xc8\xe4\xbc\xa5\xc6\x18y+\xd5\xd6\xac!\xf2\xd3\x82\xa6jE@\xa5\x17\xcaW\xb1\x1c,\xbf\xceDc\xcf3\x16\xc9\x19K*\x8f\x85\xc7\xea<\xcf\xfb\xffY\xbf=X\x9d\x92\x9b\xd4+C\xcaG-7\xfd%\x94\xe0T\xbfQ[\xc8?\x1c\xe5\xae\xd9\xb8\xfb\xd5\xd2\xe9\xc0\xfd\xbd\x1b\xf3\xeb\x07\xd7hhTx\xd398\x97\xfbv|kFE\x07\xfb\xc5KZ\xbe\x82\xe1l/\xb7c*\xa1\x15\xb2\xb1\xe8\x1eR\x92\xd9\xad\xd9bSD\xc1s+sS\xd7W\x84\xea|5y\xd8\x12\x19E,\x11\xda+j\x83K,\xae\xd1\n\xa2\x05\x8f\x98Q`\x8d\xe79u\x8e\xca\x12-hFXD\x17\xdd`\x97t\x11:\xcd\x16\xde\tF\xe0\xf5\x95#\xc8\xf4\xcck8\xb1[:j6\xf54Ua\':\x0b\x98\xa7&I\x96SD\xd7\xbc\x05a$\xc4\x85\xcfW\xab\xb0\xc7\xc6C\x0f\xbd\\\xb7\x86U$\x952\x9bO\xb4\xbf\x85\xa3\xc0\xf6\xc94r\xc3\xf8M\x1f\x10\x17}\x8f\x80!\x80\xe4;\x1f\xb9*w\xeb@\x08h\xf1\x9b9J\x9a\xa2\x84f\xdc\x87\x99\xc0\xc2]f\x86a\x00\xb4;(t\x84\x00\xc9G\xa6\xa4\xb0\xa0\xf9\xd0\x19\x1d\xf8!\x8a\xad\x182\xa5+\xc4\xb9\xbcrB\xa9\n\xba\rK\xf2\x88\xf6G\xde\xac\x02\x020\x9d_\x1a\x85\x88\xcai&\x1dh\xfb\xb0\x92\x19\xea\xab\x0b\x041t\xe5P%\x81q\x06\x93\xb8]\xa6\xdb\xbf\xcd&A\x12\xae$\xdf\xac\xda\xa5]\x8b\x99\x02\xab<Z\xfe\x99n\x9f\x08x=\x08\xce\xab\xfc\xe6\x01\x877H\xf5\x1e\x95}v\xf2\xea\xe0\xbd\xd3\x17;\x90\x9f\x07%\xceX\xc7\xfc\x07R\xeay3\xf3\x15t\xc0\x88\xf0\x07\xe3\xa2\x02\xfd \x13\\\x00\xf4U\xc4\x84O\xce\xbd\xb3\xd1\xb5\x9e\x19%\xd4\xfd\x98\xd1\xb1\xcd\x8e\xc7-\xca?yDq>\xd6s\xfet\xfe\xe0t\x1a\xbf\xa3\x8d\x01\xd3\x8e/jk\xa4\x9c\xc8\xec\xa3\x0f\x0e\x12\xbd&y\x93\x07\xd9c1\xd7\xbcH\xcaB\xd9\x82\xe2\x1b\x80\xecB I\xa7W_V\xdb\x92\xbd\xe2\xbe\xca\xd0\xaa~\x1b\x06\x87~\x95E\x01/AA\xaf\x8e\xed\x0b>\x83\\M\x8d\xd6\xc2\xd8z\xb9y"2\x14\x0c\x88\x9aio%\xf2EeN\xb1w\xca\x83~o\xbd\xb1O\x11[\x10\x98\xa4\x9d9\xe1\x1a\x8bw1\x9eQ?\x80\xbbW\xe3:\xaft{\xb7\xc2\xeeE\'\xd1O\xc9\xd8*\xb1J\x9d\x01E\xbbiJ\xf05\x19S\xdc\':\x9c\xab\xa1r\xcd\x04<"L\xc7\xf6\xb8@4\xd3\x91\xf5\xf1-8>\x98\xa7\x18\x18\xa5I\x14\xb9\xf7\xaaK\xe5\x92\xf6\x81SS\x04\xcaOm\xc4\x1c|\x88F\x1f\xf1r\x85\xdb\xeaJ\xea})}\xe5H0u\xfe\x03\xac\xe6\x0c\x11W\xb1\xe6x\tSU^\x00T3\x02\x03\x9c\x06%\x12D\xec\xa4\tHfq\xf1\xd8g?\x85\xd4\x1d<\xc1\xdcTi\xbf\x07\xe0jvJ1O\xe0#\x15c}a[\xd8\xcf\xf0vg\x1d\xf5\xf7U\xe5\xfc\x95\x9a\x10\xe7\xe5\x12\xc8\xee=\xb3\x0cm%&\xaaMW\xcaN\t\xc7\xc8\xdd\xf2\xe8Jh\'\xed\xb4\x8a\xec\xd1\xa0\xf0v\xde\xae{\xf5mF\xe7\x18\x8dM\x97C\xb5\x91\xe7\x08~W\x9dj\xa8z!\xc5B\xf4D\xb7\xa4=,\xab\xd4j\x14s|n\xd9pUai,`s\xcf\xab!\x87\xf6\xf6k\xfc\x96\xbeA5#G\xb1R.(\x82\xbdW\xcd\xcdW;\xeb]\xf0\xf5R)\xaa\xb8\xed?m\x1b\xbaz\x89\xf5\x86\xfa\xb5J\x19\x159~:U\x1d\x17=\xb4|n\xc3W\t\x05\x03\xdb\xb8\xc1\xe0H\xc8\xf9c\xd4a\xbb\xbf\xe4N\xf8\xa4\x8e\xa0\x1ec%\xcf0\x90\xa1\xdb\x82)\xd3\x07\x06\xfd\x18\r\xcd\xe7\xd9K\x9e\x08\x108_\x87\t&\xdb\x97"\xca\x9d\x90\x90q\xc7\xc7\xb6\xfcX\x88\x9f<\xa0Z?\xa4\x9cDw7\re\xbe[8%\x90l%\xa2\x0eP\x84;\xa2\xba\x89\xc2\x93\x95\xe5\x02:\x12\xe7\xad\xad6\xf90\xcc\x0f\xd9\xd5h\x9f!&\xcb\xe0E\xd4\xd4\x96.e@M\xf5\xba\xb0\xc2z\x13\xc2*\x8d\xa1\x05\xb3\x82\\\xa8}\x12D-\xf54\xac\xf8V\x7f!\xe9\x82+|\xf2}\x04\x04\x00\xf2\xe6\x95\x08\xd5J\x10@\xc7\xd9o\xd5SH\x80\xcb\xa0\x15iF\xe3\xd3\xd6\xe9\x95f\x9c7zu1.J\xbf\x80\xae\x11\xd9ccF\x8c9 \xf7\xe0\xfeF\xce\xd1\xab\xb1o\xe ...
# len: 1952
# Secret-Key: b'\x8c\xb3"\x90G\xcee\xe7\xf6\xbcb\xe5p\xea\\\x047\x81 \xec0\xc1\x18\xc4\xde\xc1\n\xe57\xdf\xf3\xa23M\xd8\n\x8d~\x06D\x96\xa6s\xc6BfT\xcaV\xa6\xbajS\x9f%\x12\xa8d\\;\xa39u\x89`\xadkQ\xa7\xca\xa88\xd7J\x85\xfd\xb5\xe5\x07\xce\xb4I\xa5\xb8q\xbb\x95\x01\xd4\xe8\x85\xcb\xadF\xd4\x05\x01TS\x04S"\x083\x135\x11\x01R(`(da2\x05\x83\x87\x03Bx\x08\x150pE0PTXC\x15\x82G\x17A \x03\x16\x11a\x02u$\x17\x18F3#S\x08\x83\x01\x02vAU t(\x18V\x07w\x11Dx0$2ef\x82H&&\x16FQT\x02GUauR\x00qF\x02@\x02\x17(\x82E\x11\x14B6we$\x80&\x822A\x06\x85\x15%v\x83xaV1s"\x051\x088EVQ@g\x03\x04bT\x018B\x013sa&\x11H\x04Hb\x08Eg\x81s\'AAxC&\'S$XTu\x8222\x13F%b\x00\x04F\x03B\x03fs\x88v\x03\x87\'`47P\x11\x011Q1\x06\x17\x06as\'\x10rC`\x12EGG\x03%4He\x00pT\x86U8\x11\'3\x11ff\x12\x10\x88a!v\x14\x11x \x01\x00Wh\x02\x18bt4sWt\x83\x11\x07"#\x82\x04T%\x85BC\x80wX\x01C\x85Vw\x16`x4t\x14Wf12\x18x@6\x80r\x17\x87\x13vqPW\x86\x03p\x80xH\x03\x804u\x864\x11q\x18CRaQ0Sg\x83\x84t\x03\x88C\x81\x17\x13F\x84\x17rpe\x82\x11!\x11w\x82HqTH2h#Q\x10%@"6\x81vA\x07\x14&$7\x18GPEr\x11%$$A\x80\x08f\x825uap\x05 7afr\x02\x80"e\x18\x00C\'\x85\x174\'Ca0\x81P7#\x10TV\x868P2\x88h\x80x6eEa\x166r\x04\x12v\x07w\x17$SF\x847GS\x82f\x16F\x17\x14\x81Pvsxr\x87E RH3q\x85GxTdr\x04ArB\'\x05w1S`uvX\x08\x84\x06T$\x16f\x16u\x881\x01`5g\x84S0\x10xuc8t\x11\x17\x10\x14\x15AQ\x85\x805tGc`\x01\x15F6\x035!3bsh\x064\x17\x12%G\x185!T@1C\x013Q\x12the\x12F\x071&DG\x01"fUuB\x05\x84vq\x16BXtEcq\x02\x87TR\x81\x88d\x15\x880\x12U\x14RPrus\x88Hbs\x17\x17\x82EbAQQg"\x83S\x13pc\x17dCQX4\'uq6V%\x08E t6Px\x01\x18\x18QEG\x82W\x882dx@G7gX"FEC\x03V\x01rw(@\x82\x08\x03\x05\x08%\x103v0!!gU\x82UBt5540sv\x02AC1\x16xvw\x87q\x00\x14\x022uFhw!F\x84\x14XRAE(R\x06h\x118T\x00C!$\x14B$\x12\x10&\x00\x13vh6pwC%FXd\x16\x83%&cf6s\x08x@\x16\x00U\x01\x07\'t#c&\x16\x01\x044Dc\x13\x83\x03FxrA\x85RAXdE\x186\x08%T\x12xb3\x08Fd%0\x14\x10\x85\x12C\x01\x08\x13\x84E2D\x11X\x84\x83\x08d\x054QU$W8b\x07\x82\x12\x04hsf\'ax\x13d\x07EgxAw4f6\x12\x813h!\x02\x13\x84$w\x14C7\x15B7 \x08\x85\x00S6\x012u\x82\x07\x11\x87!`\x08AvwT\x858\x06DX& \x045\x82CF875\x018s\x07cDS$\x17\x08ted`b \x07\x18\x16\'#X661&\x881$r\x02\x15(wQ\x18\x17ru\'qb\x863\x87%U\x17v(\x83\x17w\x00xP2d\x01\x16"qq\x12D\x835\x02 \x165\x02\x104C\x14\x86\x15\x01d\x06`!BF\x81#\x01W\x87&aD% \x08\x12P\x87"T\x08f6\x83\x87V7\x18h\x80@t\x10t\x12\x06\x06P\x88\x10%Bf0fq b\x82\x10T\x07t2h#\x18\x82d\x04%P\x83rpsD$\x86t\'WRa8!\x85HB#\x88\x02\x84`!&\x15\x03"\x14\x80gwXxp\x08x\x03`(%acsEvX\x17\x82#\x05\x10\x18\x83B3#\x07EPP%\x05p\x87u&7\x114"\x02\x88pg\x85ba\x83Uc\'4\x14\x88P\x11\x86\x86\x13w\x00#\x02e%B\x085q\x056\x02\x88\x18\x12\'\x10\x12\x00P\x102\x05Q`\x03\x18wFq&p0275\x80r8\x81aA\x15\x07\x02\x01!r#BaU(\x82\x87\x176\x00$\x15VV\x16\x102\x12\x81\x17x\x11\x11"AX%\x02\x08e\x83@\'\'`g\x10v\x13q!\x02\'\x84\'wR \x070\x83X\x12\x04\x14XC6\x82\x15u 2\x15\x824h#\x11\x17\x13a\x85pg(S\x05U\x82\x053\x84\x102X4\x10H\x83%\x18u(v0P\x01\x025#5\x03wu\x84W\x12%\x10\x08hg\x845Tba\x13\x18\x14\x18A\x18B\x17qP\x852\x003%\x17t\x03wrHCaDg\x11V\x88$\x82AED\x04\x81W\x00\x80%FR@\x08gQ\x01`Ghb\x831$\x04(x3(\x16QH\x13p\x08 WP\x12Q\x86@gB8`8s\x15`\x88\x00H\x17\x12\x16H&\x02!\x066A\x10BV\x86\x88R\x11\x836Fube@H(p\x11\x11A\x07\x08\x82\x14\x16\x82&Eh\x18\x14fEd\x07\x043r!\x03s\xd1J\x13\x89\x7f\xf6\xcc\xae\x95)\xb6\xdf\x07b\xcb\xbcTL\x99\xe7\xf2/G\x15\x8b\xd65\x9e\x7f\x98\x86\xbe\x88\xb4\xb8\xfd\x8eI\x1a\x9b*/Ly\t\xcb\xb3\xe8CC\xcd\x0b\xaa\xe2\xf7S\x83\xe4\xf6\x14\xb3\xa5*8-\xe6gS\xf1\x97\xe5jQt\t\xb9Jr\xdbQ\xf0jH\xc6\xb7\xba\x06\x0euw\x8b\r\x9d\xbfc\xb0ZI\xbc\xd7\x07\xe8\xe6\xe2\x98\xd4\xa4\x1d\xcaE\xd1\x9e%\x80\xe9\x10\x81\x02O\'\x93"\xfb*\x07\x95\x1f\x11\x89\x02\x05\x9c\xa3Ln\xa52Ey\x03\xc27&\x05\xa1\xce\n@ e\x9b\x07u\xc3\xdbO\x8e\xaeR\xc7W\x9a\xfc\xee\xe6o\xc1\xadb\t\xff\xfd\xb4\x89\x02V\x04\x1by\x0e5-\xb7O\x0f\x05_\xd6K\x93\x089\xd6U\xa0\x13\x89\xf6v\xe3\x1e\x89\xb6?C\x85$\x1aQ\xe7\xa7\xf9O\xe5?avy\x97RwJ\xbev\xf1\x15\xab\xef\x89\x04\xaa:p\xab\xca{\x9bQ7\xcf\x0e\xa9\x17\xe3\xe62\xc1\xc4?N\xe5g\xc8\tG\xf4\x89\xbbF\xd8\x1b7\x0bn\x1b\xfc\xa6\xf8\x ...
# len: 4000
# Sign: b'\x18\xe3\xe6\x10\xe6\xf9\xc9ON\xa7xH\x0b\x96\xc9\xb19\n\xca\xc1\x8f\x86\xc8]f\xfd;\x1e\x0f\x9f\xc7\x96?\xa5\x90\x9a\xc4\xe6v\x80#i\x92Pv\x98JH~\xa6b\xb0:\xbf`f{\xa7\x9a\xf4\xb6.y\xb1j\xbc\x8e\xf6\x9c\x04`j\r+\x18\t0\xa0\xfdER\x0e\x1b\xf3\x03\xae\\\x11\x88\xa7L1N\x06\xb5Q\xbe\xd7}b\xc2\x8bd|\xaev\\\x1c\xcf\xab\x98\x91\xea\xda\x8cvn0<\xcfMgj\xb5\x07Z\xfa\xc0e,F\xc4H\x86\x7f\xdeR\x88VPA\x14eZ\x18l\xc7G\x9d\x9c\x9eXJ;b\xbd{\x85G\\\xd2\x9e:\xb4>\xc9\x8ff"k\xfb6\\\x89M\x0b\xfc\xc1\rz\xdf\xbfTP\xa7\x8e\x83\xc8\xafa\xe2\x9f\xce\xaa\xe2\xd6S\xf6\xe8wD\xbdR\xee\xd2K\xd1O\xca{\xfb\xb2\x86\x90\x1b\n\xcc\x9c\xf4\x1a\x91\xa2j[\xa1\xd8\xde\x19[\xc6\x97T\xf8\xc4b\x95\xad\xdd\xe3\xbd\xe4,\xd4r\x9f\xf8\x9eD\xb6\xc98\xc2F:o\x08ck\r\xd3\x89>g\x06\x02\xce\xac\xa1X\xff\x9d=\xcf\xf9b\xd3\xcc\xfc\x94\x028\xf7"\xbb\xe4,\xe0\x84\xfa\x06\xadd\x9dS\x06\t_\x17>\x869\xd0\x9e\xb6\xfc\x86\x17\xb6\x947\xff\xfd\xce\xe2\xe2\xd2\xf7\x95Dwn\xda|\x03\xed\xbf2te\xfb\xdd/\xad\xc0\x1az\xa5\xee:l{\xc7\xcaW[3O\xdd\xbd\x11\xf5^\\\\\x08\'\xd5\xce>\xbd\x83!\xf0\xd2\x92\xb7\x8b\xf4F?\x8e!\xebE\x14D\x85|\xb9h\xd6\'\xd2v\x0e\xdd\xa3\x00\x95P\xd0\x00\x97\xa5\x17\x80\xc8\x9d(\xe9\x8a;gz\xe1]X\x02\x99c\xaag\x95@c\x91V)A\xd1\xf0\xb5;\x96\rE\xd7E\xe4\x91\x16\xc4\xcb\x99-\xf8\x88a\x01\x03\xd7F\xf5\x89\xcc\xfb\xae\xd9\x89%\xe3\x0f\xfc\xc6\xc0\xd0\xb7\xea\xc4\x10\xb1\xf0*\xcf&5\xbbP\xd3+\xcb\xe575\xec1\x06\xb9\xb5p\x98 o\x01\xf3\xc0\x18\xc6\xc2\xeb%(4N]\x96Q\x12\x9c\xfb\xe8R~ \x954\xdc\xd1\xb6\xf5E\xb3\'\x1f\xd8j\x11\xf4\xbb\xb7\xd9\x8b\x84\xc5\xb2\x89\xf1\x86VW\xfb\xfb\x9e?\xf5M2%#\xa2\\n4\xdah\xd7Ar\x91\x163g\x8f\xa2\xda\x92\xccrW@\xdb\xe9\x95*n\xb3$uV\x93\x061\x0b\xdc\xc6D\'\xcd\xb5\xd0\xa7\x88\x19P\xf0\xe9\xac\x8bB\xdc\x01W\xd4\xd8\x1f\xc8\x15\xc4\xe4\x11\xfb\x97qy\xe2\x880U9>\xc7\xe5\n\x8ccC\xed\x13_Am\x9f\x93)UQ8K`\x17\x11\xd8\xafB\xc0F\xf4\xc8EoV\xdd\xce\xfbu\xd62\x85\xe8\x83\xef\xf0\x0c\x81\xfdc\xdb\n\xbcis(\x9f\xd5\xf9\xd1\xaa\'\xa0`6\xfa\x9b\xa3\x04&\xd8\t\xfbi%h\xa7\x06g\xf9\x80\xcf\xe8\'\xb2W\xce\xba.\xa0\xb0\x83iw!6v\x18\xb2\xe7\xf4o\xd4\xb6\xcbx81\xc4\xa4\x06\xc8\xd20\xad\xf5\x84\x1d\xf8gAe\xb91\xf9\t\xd9\xcf\xc6\xd5s\x8a\xfa\x85\x00ks60\x0b\xd7\x98\x8f*\x8a^\x83\x85\x03,?\xf2h\x02u\x93\xf1\xddB!\xbb\xd3M\xd8\x8dj\xe3\x13\xff>\xba\xa0\xe2\x9c2\xf35\xb17\x08\xda\xd6\xf9\x96\xaa\xfc\xa4\x99\xb7\xb6\xa6\x1f\x1cl[\xc1O\x91\xa9o\x96\xf5o\xa9\x83\xf8+\x9f\xfdC\xc2%\x97\xea\xde\xfb~ASX\xcf\xde<\xf1%x\x01\x1fc\x8bs\xd3\xaf\xdd\xc6N\xe4\xc8\x9a\xab\x03y\xb7k\xbcUU~D\x91\xcb.P<\xc9\xace\x8a\xa2%\xc9\x90\xcf\xff\xe0f\xc5\x85\x1d\xa5\xe8\xa4^\x15\xebG\xea\xf1\xdf\xa8\xbd\xac\xb4db|\xa8g\xab\xb0\x03\xe5\xb6\x91\xe3\xba\xfe\xb3r\xa1\x14j\xb0\xff\tO\xadK\xcc\xa0\\\n\\aJ<\'\x0c#\xb3\x0c+n\xb2\xec]c\'\xd3\x0b\xfd\x963\xdd\x04l\xe5\x89c(\x9fR\x0clt\xc8\xa31\x86\x8b\xec\xcf\x8a\xb4\xc5\xe4\xc0VO@\x876\xd1\xce)\xff\x863\x01\xd5O\x9d\x15\xb2d\x0b\xe2\x05\nBN8\xe0\x89Jg\xaa\x88\x88q \x97uG\xa2\xb5\xbe\xcdn\xe0\xc4\xac\xf8,\xaeHQ@\xd2)\xd2\xeeA\xdam\xff\xf3\x19Z\xdd\x10\xe5gxq\r\x05\xd6\xf0-t\x9a\xe6\x14\x0f\x0b\xf8\xbdz\xc2\xfb\x00\xc3;Cl\xb5\x0f\xd1N\x95\xef1\x84\x07\xf2w\xd68\x99\x85J\xbc\xc9#\xff!/\xaf\x9c\xa0\xa4\xa3\xda\x0c\xe9u\xa4\x9ax?\x1c\xe6\xf1p+\xdb\xba\xeb\xa8\x06n\xc4\xe2\xc6gm\x874\xd8o|q\x18\xb0-\xcb\xdd=\xef\xe9\x95\xca\\\xb5\t\x0eDD\xd0\xb1\x154\xba\r\xe8$\x9a\xa6J]\x9a\xac\x03\xd3L\xcb\xbf\xb77\x88\xd2^\x10\x98\x7fC\x93n\xeb|E\x88\xcfcp\xbe\x1fU\x1e^D\xa3\x05\xfb\xb0\x1f\xe0\xc2z\x11\x06nJ\xf2\x12\xfe\xa6tm\x88\xbc\xb7\x97^g\xc3\x06\xc6\x8a{\xd78\x8d\x04\x82\xef\xf7\x12x\x93\xb9\x19\xc0\x1do\xfc\xdd\xab\xf9#\xe1\x04\x92c[d\x06\x8aCy\x93\xea`\xdfW\xcds\xdf\xfaKz\\c>\xaf\r\x97\x10\xaa\xec\xd1U7\x88\x14\xe3S\xafS\xda\xfc\x14\xc5\x97}e\x06\xf1W\xedi\xd8\x0f\xd7&\x94P\x91k@\x80V\x1c\xb1\x1f\x80t\x81.\xe1\x9b\x17J\xe2\xc0)\x06\x87\xf5\xc9\x8f\xa0\xe9\x05_\x8c\xbb\xad\xcdB\x96\x85\xe2\xc4\xac\x9eBW\xb6\x82\x0f\x85\x14V\xcd\x83\x00\xa9x\xe8g\xd2\x98\xc7F\xc1\n\x84\x97\xc5o\xc4e\xfd\xf4G\x8c\x94\xcaa\x18T\xd2*\xc3\x9a\x13j\xc1\xf1\xa3{\xabo\xb2\xcf\xb2\xc1Ob0\x98\x11\xef\x ...
# len: 3293
# True

# %%
pk, sk = Dilithium5.keygen()
print(f"Public-Key: {pk}\nlen: {len(pk)}")
print(f"Secret-Key: {sk}\nlen: {len(sk)}")
msg = b"Your message signed by Dilithium"
sig = Dilithium5.sign(sk, msg)
print(f"Sign: {sig}\nlen: {len(sig)}")
print(Dilithium5.verify(pk, msg, sig))
# Out:
# Public-Key: b'o[}A\xf6\x04\xd6\xe6\xe8\xa0(5\x00\xf2\x86p\x064\tw%E;C\xb7\xbbS\xc4\xd6\xc9j\xe1\x90m\x1aN\'X-\xee\x1d,\xee\xf8\xda\x87\xb2\xe5y\xf0\xcc\xa7\xa9\xc1P}\xec*I\x89\x87\xf5\xf9\xde\xff\xf0\xb4\x0c\x12\x01\x9dk\xda\xb7\n\xeb\xb2\x0f\xed\x82\\+\xa5D\xae\x8bR\xaf #\xd0\xb2\x90T`+\x15\xd9\x8c\xb4\x98]\xa2;\xe9\x85\xa2\xe0\x0fB\x08\xf9\xe7B\xf7\xa9a!\x1a\xf0\x83`\x12\xd2}\xf8\xf32.}8\xeefSJX\x0b3\xd5\xeb\xf0\x06b\x7f\x8c3\xd7\x8d\x176J\x17\xb9\x0f3 \x01\x9a(\xe2iQP\xc6\xd8h\xfd\xb0\x96\x0f)\x0b\xdcug\x8c\x1e\x12\n%\xf0\';T\'\xc0\xac/\x9bE\xc2m_1\x89\xebT\xdfgj\x91w\xf2[\xf6\x8f\x93\xcc\xf63\x13\xcfF\x03\xe7iM?\x9a\x11\xd2_\xfd{aD\x16jO\x91\xa7\xdfD\xb2#@\x92\xe0$Q\xdb\x0b\x1e\xe9U\xd1tcq\x11i8\x18P\x85\xb1\')JD\xf1\x92\x05"\x07O\xac\x92o\x98\x00\xe2\x94\x9eg\x1db|\xcb,\xd8\xdd\x93\xc8\xdb\xe4\x14[\xa1\xad\x99r\xf8\xf5\xf8r^\xf1\xb0\xd4\xd2\x8a\xa2\x83\xf4\x9dS\\9)6\xdb\x84\x17\xfb8\x9c\x98\xdc\xc4\xb7\x8c\xa4x\xc7\x1ca\xf7\xb8-\xbd\x15\x11\x8c\x14\xd9\xd4P/\x93Llf\x0c\x8b/m\xf5(\xcf\xc8\x9azr^\xce\xdc8xE\xc2J\xa3\x8e\x83\x97{\xc0\xce>\xa8\xa0\x12\xd0n\xc4ZNa\t\xdc\xa9\xf4NR\xc9\xcf\x84n\xf11\x15E\x91_\xae\xdd\xa6K\xcd\xe6\x85\xb2\x89\x07\x0f\xf5\x89\x7fM\xdb,7?\xfe\x83P\xe1\\\x9ee\x0e5\x0e\x9fl\x7fDn\xc1!3\x9arm\x01\x02\x0eQ&\x98\xfc\x8b\xbb\x11\xfa^\xba6\xfe\xfcEa\x1c\xabj\xb2\xf5jt{sD\xfc\x82[9}\x1b\xa4X@\xae\xf35\xad\x05\xdc\xc5\xc9\xa5VT/B\xec\x0f\x137\x1eO\xd95j?;\x8e\xf7\xa8)\x92z\xb2D\xed\xfd!\xce\xe9\xfc\x07\x1a\x1e]\xb0Y\xc4\x8b\x85=@\xa8U_\xf3\xd4\x15\x0c\xc1%\xfa;\xf5\t5\xc9V\xbe\xa2\xe5I\xa2\x9d\xa0\xc3\xcd\x96!7&\x84\x95\x0e?b\x95^\x0e9A\xab/z\xd8\xdd^\xc9\xbc\xa7 \x06\xdcU\xc9! \xb3:\r\xe7!/\x1ba\xb57\r\x13\x07H\xa9\x05\xbf\xd1\xc9\x02\xfa\x7f1\x0eW\x18J\xd1\xbca\xe0\x82\xce\xbf\x07w\xff\x13a\x19\xdb\xbe\x0c\xae\xda5\x05\x8a\x8e\xe9\xa7!2\xce\xd3:\xc2xj\x92\x02C\x9cC\xf0r\x8a\xb7}<b26\xdc\xb3o"y\x05\x88\xa0\xbbK\xdd\xf0B\x9eV\xa3@\xa1\xaa\xe3\x00\x01B\xad\xa0\xea\xae)\xbe\xf1\x8c\x02\x95\xf7\x84G\\\xee\x94?\xf1\xb1\x97z\x8d\x8d(\x05^\xc5\x05\x1c\x80\x96\xdf:<h\xf5\xf4/k52\x04l\xed\xc8p<\xef\x87\x96\xac\x13\xcc\xdaTP\x1c\x05.\xa4\xfb\xdd\x0eC\xaaQ\xe4\xee\xce\xb7!\xdbo.\xa8\x18\xe5\xc5\x81I\xc3\xdc\xf5!iP\xbdK\x1a\x1f*q\xad\x11\x1cJg\xf7\x88\xa9\xb0yR\xe1z\xaa\xc1{\xa9\x1co\xa1Pw\x06\xe9\xdceb\x00\xfc\xec\xa1f\x04\n#_h\x82\x9e#\x13O\xaa\x8c0\x89\x98\xaa\xc7\xce\xb5\xf7\xf6"\xdc\xef\xca\x88\xe8\xfd[bu\xae\xff?Cp{\xf3\xf8B\xac\x8fH\xe9\xa1(J:\x9a,Y\x1b\x9e_\xda\t\xa4?\xa1\xd9\xe6\xf2\xbaRy7\t@\x81-r\x10@9\x1dB\xa0{jV\xba\xaf \x83\x9d*\x03\xa9\xec\x9e\xeb\xea\x9b\xc3\xe0\xac\x9e\x16\xa7eCl\xa7\x06\x88\xbd\x87\x037J\x03*\xd6\xf5\xe86j<Vvu!f\x0b\xbd\xfc,\xb9\x85Kj\x91\x91\xd0\xcf\xec\nO\x0cB7\x13\xb5\x1a\xd0\xaa\xeb\xe5h\xb1\xcb\xf6d\xe4\x06y\xbd\x9cb\xa1\x0cY\x94z=8\x89w\x86\x1b/@l\xc54U\xdc:\xff\xf4z\x9b\x11\x04\x1c\xe8>\x91\xc6,\x97\xc3&=WwhX40\xef\xcc\xafob\x9a\xcf\xb4y\xc7|C`ZF\xa3\x03\xf2\xa9\xd2\xc5d\x83\xbf\xee6\xd5\x01\xb9\xa7mf\xe12B\xc5\x91\xa7x\xde7\xb7\x97\x82\xda~\xbc\xef.ohZ\xf1\xcfuWq\xcd\x8e(\xafP\xffh\x86\x8b\xd1N4L\xb3\x02\x86tkp\xe6F\xd2\x1b\xb9&J?\x0f\xcd\x96\xb7u\xce\x84\xfd\xb1\xef\xa7EyZ\x08\x10\xc3\x90s\xcb\xf1K\xde\xc6\x07\xfb%\xa8/\x8b\xb7\xd9\xd0\xadle\xe3\xf3b\xda\xd5\x87\xc2\xef\xb8QD\'z_\x9bB\x86\xfb\x13\xc3\xc0\x96\xef\xfac\x10hq\xbc\x0173\t2_"cGR\xd9\xe3\x85\x8a\nj\xb3\x89\xf7\x90\xc6\xaa\xf3eQ\xe1\xa4\x0c\x04\xe7\x83\xf3\xe0\xb7\x82\xabf\x80\x18Ke-\xe2.\xe8R9\xe4\x15\xbd\x15\xcfa\xcbG\xb1\xc3\x96D\xe0\xedH\x88\xc2\xa5\xb5\x1f~\x12\x99\x06}L\xa6\xa9o\'\x8c\x00H\x9cN6\xe3\xd7!"\t\xa0*\x85c\xd8\xe63\x0e\x8e\xe7\x82\xe4\xae\xba>\xd0\x87\xca^D\xfc\x92s\xe3\x1b3U\x93\xfa@C\xbe%\xf0v\xa9\xcd\x11^~\xe7\x1c\xa7Nk\xbak\xf0\xfb\x18\x14\xc2\xed\x80-\x90\xa0|\x9eu\xc2`\xf3\r\xc1P\x8d\xb7\x9a\xc9\x0f@\x98\x8fe\xb4\x05\x1ep\x81\xe3\x97\xd8\xae\xbf\xae\xd2\x98\xf5\xf9\x7f^\xf94\x84\xf0{\xfd2\x1f\x00\x855\xbd\xe9}uO\xbb\xf5\xd4e}\x02\x1b?\x8a38\x0fUy\x9b\xd3\x8d\x93\xecs\x12\xce\xfb7z,\xde-u(\x17\xc4\xf1\x1e\xaag\xb3kYo}\xb6\xab\xf0h\x8dM\x96\xc0\x86\x0f>M\xb3\x96\xfc\xf8C\xd4\xba\x95\x9b\xb9\xa8 ...
# len: 2592
# Secret-Key: b'o[}A\xf6\x04\xd6\xe6\xe8\xa0(5\x00\xf2\x86p\x064\tw%E;C\xb7\xbbS\xc4\xd6\xc9j\xe1\x8e\x87\x12ig\xac;y\xd4\x9e\x85\xbb*\x16\xd3\xe6\x1f\xdbo8\x0bdT\xc3\x8aL\x90\xb5\xf7=D\xfa\x176\xab\xb6\x03\xbeU\xdb\xdcC\x05\x8d\xa2\xd6\x17\xb8/R \x1cW\xcfO\xf2=yW\xc1\x01\x10\x15\x1d\x9b6d\x0b\xa5eK \x8e\x1b\xb0\x80\x08Ab\x04\x94\x11#\xb1\x91\x13!\x8a\x11B\x0e"\x01(\xdc@1K\x00l\x10\x15A\xdc\xa4L\x18\x121\x01\xa8,\x1b&\x8eP\x94D\x8b6\x04\x8a\xb2\x84\x948D\x83\x10\x92\x03\x060\x00&p\x1a\xc1p\x14Bh\xc1\x80p\xa1&E\x14@2\x184HZ\x80\x84\xd1\x80 \xd3\xa6\x85\x1a\t.\x14\xa8p\xc0\xb4\x08\xa2\x08A\x18\x91)\xdb l\xe4 j\xc08i\x083\x92\xd9$*\x049!\x1a9(\x00\xc6H\x84\x94H\x08\x15"\xda"*d&\x10\x007.\x88\x04F\x92\x02dd\x88\x10\xa2\x94A\xc1\xa4I\xa1@\x88J\xb0,\x8b\xb0d\xe38\n\x03(i\x03\x04\x00\x88\xa2E\xc4\xc2-\x14\x85\x8c@@\x84D0%\xe0\x96\x01\x812\x06\xe38p\xcb\x82\x89 \x87\x81dF\x89\xcc\xc8%\xa0"R$\x19b\xd2\x84\x8d\x01\x86L\x83\x06\x02Y\x94I\x04\xb8!\x13\x05aD\x00Q\x1c\x80M\x90\x16n$\x08\x05#\x11-\xd9\x98\x10\x838\x84\xa1$ \xe2\x90\x80B\x92\x0c\x19\x86\x8d\x83\x06F\x1c\xa7\x85\x1c\x13\nH\x04P\x81 F\t\xa0\x01\x02D"K\x88%\xe1@-\xdc\x94\x8d\x1a\x15\r\x12\x13H\x92\xb4\x89\x1c\x95\x91\x12\x11H\xa0\x90EQ\xb0%\x80\xb2\x90\xe4\xa4\x84\n\x80PI\x82M\x0b\xa2D\x98 \x88\x13H\x05$\xc6\x8c\x84\x88l@\x12\x82\xc1HR\\\x16e\x0b6\x8c\x98 R[2\t\x8a\x98h\x0bGlR$iP$Q\x13\x84 \t\x05(\x02\xb7\x00\xcc\x02\x10B\xb2p\x94\xb8q\x10\xc4a\x0c\xb6LXFa\x08CP\x19\x90\x0c\x03!-\xc4\x88\x10\x00Bm\x90\xb8\x8d\x8c\xc4i\xccD\x81\xa2\x08\t\x1a\x89h\xa3\xc6D\x135l\xc04\x80\xc20\x85\x9c\xa6,\x89@p\x91\x94q\x19\xc7\r\x14\xb5\x01\xa2\x10"#\x94%Q4b\xd20\x92@\x00P\xd4&"\x99\xc6\x05#\x90\x04\x14)\x8aS !\xd3\xa2h\x1aBD\xdb\xb8\x05\xd2\xb8-\x83\xb0\x89\n@I \x98A\xa24-X2\x8e\x94(\x8c\x02\x94l\t\xa7LS\xa6p\x98B\x84 3\t "j\x1a\xc7m\xe4 \x05\xe1\x82i"\x15*\x8b8fH\xa8l\xa1\xc4D#@1\x02\xa1M[D \x0c&f\xd4\xb6m\x80\xc2\x80\xdb\x88\x10\x88\xc2A\x1a\x18l\xd8\x84\x88\x12\xa9\rX\x08\x8eB\xa2\x8d@\x18(\xe4DQD((H\xa2\x90\x1a\x97A\x198(K\xb0%\x83\x04FR\x10\x89"ED\x03HfR\x14j\x04\x95IaF)\xda6i\x03\x93ER@\t\xcc\xb8P\x83$\n\x10\xb1\x8c\x04\xc0 \xd9\x80E\x8c0n\x10\x13\nK\x88$\x1b\xa7\x11\x0cDb \xa5aB\x14Q\xc9\x14H\x8a\xa4\t\x8bDf\x1b\x96Q\xdc\x80\x01\x11&\x85\xdc0Q\x19A`\x0c\'e\xcc8\t\xa0&m\xcb\xb8@\x8c\x92AK\xc4dZ2N\x04\xb9@L6@\xa0Db\xe1\x88\x10\x9a\x12(#\xb7\x04\xdc\x08\x06\x84\x00Q\x18DAb6"\x01\x02\n#\x11\r\x00\x85\x11\xc48\x85\xd38\x12\x82F\x8e\x1c7\n\xc1\x88`\x144l\x84\x82\x91d(\x8a\x02\x84@!\x19\x8e"\tmZ4d\\(\x90\xcc6\x05\xe4Ff\x10\xc6Q\x8a \x82\x08\x12\x82d\xc0\x90R\xa6L\xd8\x92\x10\x10\x98!\x01\xc60\xca\x12f\x0c8B\xd3H\r\x12\xa90\xd2\xc8\x88\xc9$\x01\x1c\xb2M"\x01r\xe1\xc4I\x19\x91q\xa0\x02"\xc9$0L\x90\x11\xc8(F\x0b)\x92\xdb\x00\x82#\xa5A\x1aC\x81\x11\xa0\x8c\x822%\x11\xa5\x90D"\x0cJ\xb4\x8cJ4\x84\xd2\xb0m\x0cC\x0ec$E\xc1\x02\x90\x08\xa4@L6\x04\xc3\xa6)\xd44\x88\x04\x13\x10\x1a\x08aC\x06I \xa71\xa1\xb8Q\x010(\x04\x17\x88\x81\x92D\x88F\x11d\x10iS D\x08\x04\x86\xe2\x18\x84\x01I\n\xa4\x06J\xdb\x80e\x9a\x14"\tI-\x10\x90p\xc9B0\x0b\xa9lT\x92\x05\x1c\x13\x91\t6.\xcb$,"\xa7PK\xc4e\xc3\x80H\x0c%\x92\x89DI\x0b\x04\x81\x01\x97\x00\x12\x07\x80bFI\x126r\x12B\x06 4\x12\x908mI2,\x13\x89\x8d\xe4"E[\x18\x8dKB\x05`\x92$R\xc0d\x105\r\x192a$\x07\x06[\x90@\x84" \x19\xb8H\x882$BF\x81\x00\x17 C\xa2\x8d\x01\x05\x88D\x86H\x9a\x04N\x1c0\x11Y\xb4\x90\xd4\x14\x10\xcc\x840\x89\xc2\r[$\x82"7 \xe1\x18Jb0\n\x00\xa3\x81\xa4\xa0mJ\xa8\x84\x1b\xb9\x85\x14\xa1\x88@\x100\x00\x80(\n\x08h\x99\x16d\xdc\x86\x81\x00%-c E\x13B\x86!\xb7\x08 \x11)\x00\x85Pc\x16\x02\xe4D\x10\x99\x16.\xa3\xa4\x00\t\x00\n\x8a\xa8LP6\x8e\\\xc0p"\x15HL4"\xdb2n \x86e\x88\xa4i\x04\x90\x90\x81\xb6Q\xa4F([\x10(\xd9\x040\xc4\x98H\xa3"\x12\x12B1X\x18P\x19\x06@\xe08E\x0c\x92m\n\x10$\x02\x11\x8aY8 \x11\x15`\x8a\x12n\x01\x98aB\xa4 \x19\x96\x01\x1bG2\xe2\x10`\x03!d\x02\xa80\xa3\x80@#3\x0cD&Q\x13\xa41\xc8\x06 "%p\x8a\x82`P\x16D\n\x97\x04\x0b\xb9mK\x96L\t\x05F\x032a\x13\x87%X\xa6\x10\x08\x12\x01\xcb0\r\x99\xb8%\xc4\x00D\x1a\x04b \xa2P\xd1\x18)\x88\x16\x92L\x84\x0cY\x92\tS\xc8\x08\ ...
# len: 4864
# Sign: b'\xa1\xac\xdd+u\xbc\xad\xd2\x9cqtm\xf1^\x9f\x0ba\x95\x11\xf6\x01\x17\xe5\xaac\xd0_\x01\xd0\xc2\x89T*5\x02|qSK{\x04G\xc7\x833M\x1a\x06\xa7\xba\xa9\x0c\xd9\xcb\x1c\xff\x88H\x99"\x9a\xdf\x8d\x93\xf1<\xf2B\x9e\x0c\xd9\xe8\x92\xfa\'x\x90uV\xd2E\xdc\xe8\xdaVv\x96?\xa0\xa2\xb4\xf2\xf1\xa5\x91+\x03v\xdc\x17\x8aopb\xfe\'%k\x05\x81\\\xb6a\xdac\x89\xde\xa8\x9e\xb4\x8f\r\xd0\xb8HpD\xc6\xd66!\xf1\xf8D\xfa\x10#\x1a\xef|)\xc0\xb5reFU\x88K\xdcH\xdf\xc54\xba$}\xeb\xa0T\xbc@\x9e\xd6\x8c$\x13\xa9\xb4\xdc\xe4|\x93\xd4S\xa4M\x85\xe6\x9d\tj\xae\xdb(1\x9f\xfe\x06\xccPo\x06\x12\x91\x8d\x1a/\xc9/\r\x19\x04P\x0e\xf2\x8a\x01\'\x9b\xd9I\x91v\t\xcd\xf84\xa0VJ\xeeY\xdbd\x8c\xed\xaeD\r\xfb]\x8fW\xc0HqiG\xfb\xfd0l\xb6T\xadfnR\xe3\xc8@\xd0>\xcd\xa2\xfd\xde\xfe\xfc\xe1\xc1\xe5\xea1\x8f,\xcd\x88\xa1\x1f\x10Lq6\x96\x1c<2\x01.\x82\xa8\t\xc5\x99}Q\x7f\x14a\x03u\x11U\xb3`\xc5\x02\xfb\xdc\x18\xcaL\xdb\x94\xc5\xeb\xc4\xc63\x10I~\xc3\x97\xd0\xe4*\xbd\xbbR\\\x93]\x1f\x8a_\xcc\x9f\xf1\x9f\x97\xd2\xa2\xd4\xe0])\xbb\xb5\xb0\xd7,\xd7\xde\x7f\xa1\x06gW\t\xe3\xb05I-\xa8\tr\xadX\xa2\x03\xd0D\x18\xf1\xdb\xa1@\xc4\x83z\xbcn\xad\xb2\xdeo\xb1H;\xa1o\xfb\x88tV\xce\x9c>\xf0\xce\xc2-\xdcJ\xbe\xf7\xb1vu\xe1\x8a]\xb9\xda\xff\\\x0c!\x92\x82T\xf8\x00\xd6\xd8OL\x18\xcaK\x0fRI%\x14\x1d\x90\x9e\xae\xb8\xdf\xddlY\xc1\xc7_3]\xe2\xd2\xd3\x01)\x8b2\x06\xdb\xf6\x84\x03`o\xc5m\r+\x1c#o\xd4\x0c\x99S\\F\x1c\n\xfaJ\xea\xab\xf2\xa9\x93\x87p\xba#rp\xea\xc1\xacM\x85\xb7\x84G\xbe\xebk\xacu\xfbV\xf0S)\xfc\xa2\xb1\xe6\x87\xc7\xdd\xcec+\xf4\xc5\xf3&\x9d\'\xce\xab`\xe7\xd1\xff\xe5\xf9\xaa\xb2\x8a\xfb\xf6\xf7\xa3\xf7\xb6\x80\x99\xf5\xa7\xfd8\x881\xf0\x86\x004\x1d\xcfi\xf0\x8bO{L\xb3]\xeb3{n%\xd5\xdb\xcbu\xdc\xd6D7\x8e\xb7y]\xa0C\xe4\x0b\xcfB^\xa7D\xd9D\xe5e\x84[5\xdc\xd9\xfd^.\x90NO7KY\x8e:SG\x9b\xa1\xe1P\x8aEVj\x19\xe9|\xfc`\xb1M\x1dZ\xdf\x9b\xae\x02\x15p\xc6h\xbb$)\xd2\x1b\xad\x13\xad\x92NU\xcb\xed;\x94\x8d\xc2\x1f\xed\x84\xdf-\x07#\xc0\xf7\xf0_3z\x12\xb2{\xab\xfa\x88\x92\xf6\xe9d0H\xe9\xc6\x1fM\xcdH]\x0e\x82\x9d\xc7|\x85\xdd~A<\xf0\xf8XY\x7f,sQ\xf6`B\xacYZI\x92\'\x1d^\x10K<\x11cb\xc4T\xd2\x96\xfa.\xf6\x8d\x0b\x8e\xb8\xabE?HkOE(\xf0X\x1a\\S\xc9\xd5\x8c9\n\xab\xdf\xed)&\xc0\x91\x88\xf2>F\xb5\xa3\xd7_\x1fh\xe6"\xbfE\xb7k\xca\x84\xff\xdc\xe5[i\xd0\xc1\xa1\xa2\xcfc\xdf#.\xabX\xa85\n\x02g\xaa\xfc9\xc8\xda\xa7+\xb2\xc1\xd6\x97\xccm\xd1g\xc3A\xb0\xd2 \x8c\x96\xcd\xb9\x9b\xef+r\xdd\x91\x8aA\xaf\x82\x88\x99\x97@\xca4\xb6\xa3o\xd0\x14$\xcbC\x11\\\xa2,\x9bki$\x16q\x04\x9f\xd0-]\x0fF \xfd\xa2\xcb\x03\xe4yi_\xff\x83\xcfS\'U\x97\xdc-(\t\x8d60\xb6|\xbc\xea$\x02\xc8\xd0\x8d\xb7s\xc86\xb6$0I\xd7L\xc3\xa4?\x92\x08\x1cG\xe9\x07\xa4\x02\x82\xef2\xde#\xd8\xb5\x0b\x96\xe1^A#\xe4 eb~\t\xc4\xc2\xf0\xa6t\'\xf1\x1c\xe9L\xd5\xb3\xcc\xe5-\xf5\'\xde\x8d\xf7gOy9p\xebZ\xcd\x00\xfe\x04S\xd5\x14\xda\xf5\xab\n@y6\x9f\x13\xd4\xae\x0c\x93\xe4\xbd\x15\x86^/\xab\xa0Gb/Q\xd1H$u\xad\x1a\xe3k\x0fR\x1aS1\xa9H\xeb\xec\xf6\xd3\xc6\xd9\'\xe3\xab@R\x000\xb3\xb2s\xfb&\x16yk K\x0b5\xff"\x03\x80\x04\xd2V\xbaP\xad\xe60\n\xad\xfa-\x88\xb4\x9b~,\xdcS_A\x1e\x81}jO\x7fs\xa4\xed\x98\x8a\xc8J\xd8\x8a\x94v\xff?\xa9<\xfa\x19\xb40\xb5\xf8d\x14j\x8e\x02\x92d/CC\xcc\xc8\x8a(\r\xc3\x85\xd7\x89\x9b\xed\x12z#\xaaAY\xff\xef\x0b\x1d\x137\xd2\xf8\x1d^Hl\x1b \x9a\x8e\xd3oF\xc7\xe0\xc3\xc5\xb9\x0bb\x1e\x05}\xda\xa94w\xb3\x1c\xbe\xcb\xcf_\x11vq\x93Eq5F\xd6\x16\x96\x0c#:9X\xfe\xef\xd5r\xeb\x92\x8ap\xd7\xfe\x83>\x92\xb1i\xcas\xc9\xf0`\xd5\x9bqa\xec\xba*%|zW\x85\x1e3\x13\xfeF\xf2\xc8l+\xaf.\t\x0c\xc7\xb4\xc5_k\xa3\xb4\xe0\x18pvP\x11\x1d\x9bY\x1d]\x9e\x8f\x0c\x19\xe4\xae\xe8\x86G\x02Z\x8f 7i\x90\xb9\xbf\xb5\xbaI\xcc1\xc3\x80\x8d\x9a\xf0\xc0\x14\x95a\xcf\xc2\xae2\xf90A<\xc9-K\xee*2\xee\xf0eh\xe2s\x8a\xfcRv\x00\xea7\x0f3\xc2\xf9=\x119\x83\xde\xd3\x96V\x8e\xb6\x01\xb6\x18\xbd2\xcc\x1a\x15/\xaa\x96\x08\xe0W\xfc>\xab\\\x97\xf6\x87\xfb\x1e8j\xfd\xa4K\xaf\x99\xb9\x0b+\xc6\x0c\xb7\xa5(\xae\x8ca\x91\x9cX\xdb\x032\xbb\xe0\xd9\xf9\xf9\xa7\xf0j\xbf\xbe\xe5\x89\xf6\x96\xae.\xa0\x84\x1a-p9\x85\xff\xb54:YB\xd2\xde\xe1\xb7*\x1e\xefJ\xffr\xf6\x06A\x8d\xa1\x98\x9cx\x07*\xc9W\xd0\x1f;m\xf0 ...
# len: 4595
# True
